# %%
# Reference : https://ampl.com/api/extra/python_quickstart.html

# %% [markdown]
# ## Step 1: Path Setting

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import random
from operator import add

# %%
from bokeh.layouts import row
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d2704748-893a-4b55-8f1d-2e4f9ee3c9ff">Loading BokehJS ...</span>
#     </div>

# %%
from amplpy import AMPL, Environment, DataFrame

# %% [markdown]
# ## Step 2: Create an AMPL object

# %%
ampl = AMPL(Environment('C:\\Users\\user\\Desktop\\OR_Kung\\AMPL'))

# %% [markdown]
# ## Step 3: Select the solver

# %%
ampl.setOption('solver','C:\\Users\\user\\Desktop\\OR_Kung\\AMPL\\cplex')  #'gurobi'

# %% [markdown]
# ## Step 4: Define the model

# %%
# ampl.read('FairCHBF.mod')

# %%
ampl.eval('''
set I;
set J;

param B {J} >=0;   # benefit of doing the job
param C {J} >=0;   # cost of doing the job
param K {I} >=0;   # capacity of machine 

var X {I,J} >=0 binary;   # Decision var 1 # 其他問題寫"integer"
var MinBnft;              # Decision var 2

maximize Benefit: MinBnft;

s.t. Capacity {i in I        }: sum {j in J} C[j] * X[i,j] <= K[i];
s.t. ProdTime {        j in J}: sum {i in I}        X[i,j] <= 1;
s.t. MacBnft  {i in I        }: sum {j in J} B[j] * X[i,j] >= MinBnft;
s.t. Arrange  {i in I, j in J}:                     X[i,j] >= 0;

s.t. MinBenefit : MinBnft >=0;
''')

# %% [markdown]
# ## Step 5: Define the initial data

# %%
# batch 要做成:
# [ num_machine, num_job, cost, benefit, capacity ]

it_n = 100

def batch (num_machine, num_job, relation_bc, capacity):
    
    m = num_machine
    n = num_job
    
    list_c1 = []    # 內含 100組 n個 job的 cost 組合
    list_b1 = []    # 內含 100組 n個 job的 bnft 組合
    list_k1 = []    # 內含 100組 由 n個 job 加總算出的 k
    
    for i in range(it_n):
        
        list_c2 = []   # 內含 n個 job的 cost
        list_b2 = []   # 內含 n個 job的 bnft
        
        for j in range(n):
            c = int(random.randint(0,50))
            list_c2.append(c)

            if   relation_bc == 'L':
                b = c

            elif relation_bc == 'X':
                b = c**2

            elif relation_bc == 'A':
                b = c**(1/2)

            elif relation_bc == 'R':
                b = random.randint(0,50)  
            list_b2.append(b)

        if   capacity =='N':
            k = 10000 # no capacity

        elif capacity =='L':
            k = sum(list_c2) / m

        elif capacity =='T':
            k = sum(list_c2) * (0.75) / m
    
        list_c1.append(list_c2)
        list_b1.append(list_b2)
        list_k1.append(k)
    
    return  m, n, list_c1, list_b1, list_k1

# %%
# Test OK! 不要在正式 run 100組時  print，會很慢 >"<
'''
instance = batch( 5, 20, 'A', 'T' )
print(instance[2])
print(instance[3])
'''
# Out:
# [[22, 48, 34, 16, 40, 30, 5, 48, 34, 17, 18, 5, 41, 26, 14, 12, 26, 45, 15, 35], [43, 35, 6, 18, 16, 31, 9, 8, 12, 35, 13, 23, 50, 48, 30, 48, 50, 35, 25, 29]]
# [[4.69041575982343, 6.928203230275509, 5.830951894845301, 4.0, 6.324555320336759, 5.477225575051661, 2.23606797749979, 6.928203230275509, 5.830951894845301, 4.123105625617661, 4.242640687119285, 2.23606797749979, 6.4031242374328485, 5.0990195135927845, 3.7416573867739413, 3.4641016151377544, 5.0990195135927845, 6.708203932499369, 3.872983346207417, 5.916079783099616], [6.557438524302, 5.916079783099616, 2.449489742783178, 4.242640687119285, 4.0, 5.5677643628300215, 3.0, 2.8284271247461903, 3.4641016151377544, 5.916079783099616, 3.605551275463989, 4.795831523312719, 7.0710678118654755, 6.928203230275509, 5.477225575051661, 6.928203230275509, 7.0710678118654755, 5.916079783099616, 5.0, 5.385164807134504]]

# %%
machine_job  = [(5,20)]
capacity     = ['L','T','N']
relation_bc  = ['L','A','X','R']

# %% [markdown]
# ## Step 6: Model Build-up & Solution

# %%
# 迭代 instance

MinBenefit_ijk_sn_1 = []
MinBenefit_ijk_sn_2 = []

for i in machine_job:
    
    num_machine = i[0]
    num_job     = i[1]

    # 印出編號，但從1開始算而不是從0，再讓 [1,2,3] -> [M1,M2,M3]

    machine1 = ['M']*num_machine
    job1     = ['J']*num_job
    machine2 = map(add, list(range(num_machine)), [1]*num_machine)
    job2     = map(add, list(range(num_job))    , [1]*num_job)
    machine2 = list( str(x) for x in machine2 )
    job2     = list( str(x) for x in job2     )
    machine  = list (map(lambda y, z: y + z, machine1, machine2))
    job      = list (map(lambda y, z: y + z, job1,     job2    ))

    # AMPL sets

    ampl.getSet('I').setValues(machine)
    ampl.getSet('J').setValues(job)
    
    for k in capacity:    
        for j in relation_bc:

            instance = batch( i[0], i[1], j, k )
                       
            MinBenefit_1 = []
            MinBenefit_2 = []
            
            for p in range(it_n):      
                
                # ====== Model 1 ======= : 一組一組用solver算 IP (or linear relaxed LP)，每種senario要算 100組 再平均
                
                # amplpy DataFrame
                ampl.setData(DataFrame(
                index=[('J', job)], 
                columns=[
                    ('B', instance[3][p]), 
                    ('C', instance[2][p])
                ]
                ))

                # Pandas DataFrame
                df = pd.DataFrame({
                    'K': [ instance[4][p] ]*num_machine
                }, 
                    index = machine
                )
                ampl.setData(DataFrame.fromPandas(df))

                # Solve the problem
                ampl.solve()

                '''
                # Create a DataFrame with Decision variables
                Var = ampl.getVariable('X').getValues().toPandas()
                print(Var)
                '''

                # Display the objective value
                MinBnft_1 = ampl.getObjective('Benefit')
                MinBnft_1 = MinBnft_1.value()
                MinBenefit_1 = np.append(MinBenefit_1, MinBnft_1) # numpy.ndarray
                
                
                # ====== Model 2 ======= : 一組一組用 CHBF算，每種senario要算 100組 再平均
                
                # 將 job 按照 cost (workload) 排序

                list_c = instance[2][p]
                list_b = instance[3][p]

                list_cb = list(zip(list_c, list_b))        # [3,5]  [8,1]  -> [(3,8),(5,1)]
                s_cb    = sorted(list_cb, reverse = True)  # [(3,8),(5,1)] -> [(5,1),(3,8)]
                o_cb    = list(zip(*s_cb))                 # [(5,1),(3,8)] -> [(5,3),(1,8)]

                list_c  = list(o_cb[0])                    # [5,3]
                list_b  = list(o_cb[1])                    # [1,8]

                mach = []                 # machine
                ca = instance[4][p]

                for r in range(num_machine):

                    mach.append([])    # machine set中安排一台台 machine 被 append 進來
                    mach[r].append(0)  # 初始的 benefit和 是 0
                    mach[r].append(ca) # 初始的 capacity  是 ca

                for s in range(num_job):

                    mach = sorted(mach)                           # 按照 benefit和 由小而大排序
                    # print(machine)

                    for r in range(num_machine):                  # 由最小 benefit和 的先開始

                        if list_c[s] <= mach[r][1]:               # machine r 還有 capacity 餘裕

                            # print(mach[r])
                            mach[r][1] -= list_c[s]
                            mach[r][0] += list_b[s]
                            # print(mach[r])
                            # print('=================')
                            break
                
                mach = sorted(mach)                               # 再一次 按照 benefit和 由小而大排序
                MinBnft_2 = mach[0][0]                            # 將最小的 benefit和的 machine 取出來
                MinBenefit_2 = np.append(MinBenefit_2, MinBnft_2) # numpy.ndarray
                
                
            # ====== Model 1 Objective value: ====== #
            
            list_M1          = list(MinBenefit_1)
            MinBenefit_100_1 = sum(list_M1) / len(list_M1)
            MinBenefit_ijk_sn_1.append(MinBenefit_100_1)   # i*j*k 種 senario 迭代
            
            # ====== Model 2 Objective value: ====== #
            
            list_M2         = list(MinBenefit_2)
            MinBenefit_100_2 = sum(list_M2) / len(list_M2)
            MinBenefit_ijk_sn_2.append(MinBenefit_100_2)   # i*j*k 種 senario 迭代
            
            print('=========================' + str(i) + str(j) + str(k) + '=========================') # 分隔           
            
print(MinBenefit_ijk_sn_1) # list
print(MinBenefit_ijk_sn_2) # list

MinBenefit_ijk_sn_ratio = list(map(lambda a, b: a / b, MinBenefit_ijk_sn_2, MinBenefit_ijk_sn_1))
MinBenefit_ijk_sn_ratio
# Out:
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 43530 MIP simplex iterations
# 5860 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 166 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 40827 MIP simplex iterations
# 6610 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 6907 MIP simplex iterations
# 1060 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 43304 MIP simplex iterations
# 7825 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 13199 MIP simplex iterations
# 2335 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 288 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 244 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 119354 MIP simplex iterations
# 15268 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 413 MIP simplex iterations
# 97 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 49851 MIP simplex iterations
# 8167 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 180 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 74
# 127 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 73
# 190 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 1861 MIP simplex iterations
# 373 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 394 MIP simplex iterations
# 143 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 2260 MIP simplex iterations
# 454 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 2321 MIP simplex iterations
# 649 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 164799 MIP simplex iterations
# 23180 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 43278 MIP simplex iterations
# 8464 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 72
# 62099 MIP simplex iterations
# 15589 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 38003 MIP simplex iterations
# 5572 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 54476 MIP simplex iterations
# 9029 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 150 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 39309 MIP simplex iterations
# 6335 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 225 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 167 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 256 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 185 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 66977 MIP simplex iterations
# 11051 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 125
# 593637 MIP simplex iterations
# 43187 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 704 MIP simplex iterations
# 110 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 1921 MIP simplex iterations
# 486 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 206 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 1596 MIP simplex iterations
# 211 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 9991 MIP simplex iterations
# 2502 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 123
# 223 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 41578 MIP simplex iterations
# 6163 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 53128 MIP simplex iterations
# 7999 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 195 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 42540 MIP simplex iterations
# 6402 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 2091 MIP simplex iterations
# 517 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 74
# 5345 MIP simplex iterations
# 1273 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 110053 MIP simplex iterations
# 14039 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 34670 MIP simplex iterations
# 6723 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 35481 MIP simplex iterations
# 6642 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 42523 MIP simplex iterations
# 6835 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 200 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 131
# 517832 MIP simplex iterations
# 37818 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 120
# 6865 MIP simplex iterations
# 1803 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 3886 MIP simplex iterations
# 729 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 233 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 34356 MIP simplex iterations
# 6620 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 184 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 92253 MIP simplex iterations
# 9973 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 29931 MIP simplex iterations
# 6968 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 28189 MIP simplex iterations
# 5916 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 27781 MIP simplex iterations
# 6578 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 217 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 122
# 41047 MIP simplex iterations
# 6306 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 116
# 4005 MIP simplex iterations
# 780 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 64
# 188 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 32145 MIP simplex iterations
# 6873 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 198 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 191 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 1231341 MIP simplex iterations
# 118611 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 6676 MIP simplex iterations
# 1379 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 305376 MIP simplex iterations
# 28505 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 236 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 35432 MIP simplex iterations
# 6264 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 690 MIP simplex iterations
# 88 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 175 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 226 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 78
# 35916 MIP simplex iterations
# 7373 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 105
# 10440 MIP simplex iterations
# 1275 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 181 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 124
# 204 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 893829 MIP simplex iterations
# 88421 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 42277 MIP simplex iterations
# 5760 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 238293 MIP simplex iterations
# 21286 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 42653 MIP simplex iterations
# 5166 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 33675 MIP simplex iterations
# 7077 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 40149 MIP simplex iterations
# 6314 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 5508 MIP simplex iterations
# 1302 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 118
# 2826 MIP simplex iterations
# 627 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 39426 MIP simplex iterations
# 6496 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 125
# 34087 MIP simplex iterations
# 3897 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 12010 MIP simplex iterations
# 1873 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81
# 2320 MIP simplex iterations
# 552 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 134954 MIP simplex iterations
# 15973 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 125
# 4096 MIP simplex iterations
# 1009 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 158486 MIP simplex iterations
# 14764 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 31557 MIP simplex iterations
# 6694 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 41669 MIP simplex iterations
# 6974 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 105
# 134249 MIP simplex iterations
# 11019 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 572 MIP simplex iterations
# 74 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 73
# 197 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 1925 MIP simplex iterations
# 775 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 699 MIP simplex iterations
# 114 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 1567 MIP simplex iterations
# 413 branch-and-bound nodes
# =========================(5, 20)LL=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 53
# 439 MIP simplex iterations
# 45 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 69
# 182 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 5730 MIP simplex iterations
# 1278 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81
# 3423 MIP simplex iterations
# 662 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 20820 MIP simplex iterations
# 2830 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 1359 MIP simplex iterations
# 201 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 78
# 503 MIP simplex iterations
# 108 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 76
# 6373 MIP simplex iterations
# 1717 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 58
# 4954 MIP simplex iterations
# 1160 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 60
# 181 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 2987 MIP simplex iterations
# 466 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 69
# 13535 MIP simplex iterations
# 3034 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 56
# 1592 MIP simplex iterations
# 345 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 211 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 60
# 136 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 47
# 6569 MIP simplex iterations
# 1065 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 65
# 219 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 76
# 4843 MIP simplex iterations
# 1344 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 66
# 169 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 77
# 183 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 68
# 176 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 71
# 156 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 67
# 2866 MIP simplex iterations
# 310 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 204 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 72
# 146 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 859 MIP simplex iterations
# 154 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 72
# 189 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 165 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 78
# 773 MIP simplex iterations
# 122 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 72
# 2463 MIP simplex iterations
# 500 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 69
# 2010 MIP simplex iterations
# 438 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 73
# 844 MIP simplex iterations
# 131 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 64
# 1565 MIP simplex iterations
# 563 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 68
# 4823 MIP simplex iterations
# 886 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 690 MIP simplex iterations
# 124 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 10021 MIP simplex iterations
# 1665 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 69
# 176 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 65
# 157 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 63
# 4761 MIP simplex iterations
# 1087 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 69
# 213 MIP simplex iterations
# 7 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 68
# 211 MIP simplex iterations
# 11 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 67
# 9762 MIP simplex iterations
# 1752 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 7460 MIP simplex iterations
# 1530 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 74
# 4849 MIP simplex iterations
# 503 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 6652 MIP simplex iterations
# 1667 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 59
# 155 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 68
# 146 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 60
# 9380 MIP simplex iterations
# 1267 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 2702 MIP simplex iterations
# 597 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 67
# 199 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 16068 MIP simplex iterations
# 2695 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 46
# 9435 MIP simplex iterations
# 1481 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 65
# 210 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 60
# 754 MIP simplex iterations
# 101 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 76
# 32326 MIP simplex iterations
# 4325 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 54
# 199 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 24282 MIP simplex iterations
# 3126 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 168 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 76
# 555 MIP simplex iterations
# 97 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 69
# 181 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 863 MIP simplex iterations
# 147 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 33129 MIP simplex iterations
# 4904 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 66
# 219 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 53
# 2565 MIP simplex iterations
# 544 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 2085 MIP simplex iterations
# 567 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 1520 MIP simplex iterations
# 322 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 66
# 12416 MIP simplex iterations
# 1934 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 187 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 21017 MIP simplex iterations
# 3852 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 7790 MIP simplex iterations
# 1708 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 61
# 199 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 77
# 2398 MIP simplex iterations
# 579 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 66
# 704 MIP simplex iterations
# 122 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 64
# 175 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 61
# 177 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 64
# 2089 MIP simplex iterations
# 518 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 72
# 6328 MIP simplex iterations
# 1765 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 78
# 11700 MIP simplex iterations
# 1488 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 59
# 4987 MIP simplex iterations
# 1068 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 71
# 3998 MIP simplex iterations
# 672 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 70
# 6289 MIP simplex iterations
# 1443 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 189 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 22196 MIP simplex iterations
# 3973 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 72
# 208 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 2082 MIP simplex iterations
# 537 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 192 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 71
# 10448 MIP simplex iterations
# 2002 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 748 MIP simplex iterations
# 209 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 72
# 46728 MIP simplex iterations
# 6634 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 69
# 807 MIP simplex iterations
# 164 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 77
# 1752 MIP simplex iterations
# 614 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 63
# 193 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 219 MIP simplex iterations
# 4 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 73
# 4827 MIP simplex iterations
# 921 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 64
# 9339 MIP simplex iterations
# 1461 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 69
# 2603 MIP simplex iterations
# 551 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 3083 MIP simplex iterations
# 970 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 1836 MIP simplex iterations
# 448 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 73
# 555 MIP simplex iterations
# 141 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 172 MIP simplex iterations
# 0 branch-and-bound nodes
# =========================(5, 20)LT=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 5013 MIP simplex iterations
# 1627 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 4228 MIP simplex iterations
# 1724 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 1447 MIP simplex iterations
# 337 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 587 MIP simplex iterations
# 119 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 640 MIP simplex iterations
# 144 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 2097 MIP simplex iterations
# 641 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 118
# 1322 MIP simplex iterations
# 530 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 657 MIP simplex iterations
# 153 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 6098 MIP simplex iterations
# 1945 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 113
# 1477 MIP simplex iterations
# 541 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 6419 MIP simplex iterations
# 2283 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 115
# 600 MIP simplex iterations
# 132 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 648 MIP simplex iterations
# 142 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 118 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 1401 MIP simplex iterations
# 463 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 123 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 601 MIP simplex iterations
# 146 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 77
# 653 MIP simplex iterations
# 125 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 115
# 98 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 2054 MIP simplex iterations
# 873 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 508 MIP simplex iterations
# 131 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 155 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 141 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 6065 MIP simplex iterations
# 2712 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 2329 MIP simplex iterations
# 859 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 71 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 1840 MIP simplex iterations
# 453 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 131 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 478 MIP simplex iterations
# 93 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 2661 MIP simplex iterations
# 679 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 728 MIP simplex iterations
# 126 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 1024 MIP simplex iterations
# 275 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 178 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 139 MIP simplex iterations
# 7 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 4850 MIP simplex iterations
# 2675 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 642 MIP simplex iterations
# 111 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 116
# 663 MIP simplex iterations
# 136 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 808 MIP simplex iterations
# 335 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 2061 MIP simplex iterations
# 787 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 6696 MIP simplex iterations
# 2825 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 15963 MIP simplex iterations
# 6582 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 149 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 773 MIP simplex iterations
# 151 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 146 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 1891 MIP simplex iterations
# 668 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 623 MIP simplex iterations
# 136 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 132 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 121
# 752 MIP simplex iterations
# 128 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 136 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 5539 MIP simplex iterations
# 2958 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 81 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 2274 MIP simplex iterations
# 1159 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 847 MIP simplex iterations
# 139 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 1118 MIP simplex iterations
# 399 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 3205 MIP simplex iterations
# 1388 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 137
# 28770 MIP simplex iterations
# 12433 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 114 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 129 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 11390 MIP simplex iterations
# 5212 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 772 MIP simplex iterations
# 149 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 5205 MIP simplex iterations
# 1710 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 105
# 2434 MIP simplex iterations
# 762 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 1011 MIP simplex iterations
# 278 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 1868 MIP simplex iterations
# 739 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 23361 MIP simplex iterations
# 10081 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 559 MIP simplex iterations
# 107 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 124
# 152 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 871 MIP simplex iterations
# 262 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 1794 MIP simplex iterations
# 608 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 78
# 6482 MIP simplex iterations
# 2584 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 536 MIP simplex iterations
# 114 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 27730 MIP simplex iterations
# 11742 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 9297 MIP simplex iterations
# 3005 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 111 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 108 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 167 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 124
# 8155 MIP simplex iterations
# 3142 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 112
# 6496 MIP simplex iterations
# 3061 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 168 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 3091 MIP simplex iterations
# 981 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 126 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 654 MIP simplex iterations
# 116 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 92 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 116
# 762 MIP simplex iterations
# 170 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 4514 MIP simplex iterations
# 1470 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 135 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 123
# 19925 MIP simplex iterations
# 10238 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 119 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 6327 MIP simplex iterations
# 4045 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 619 MIP simplex iterations
# 124 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 694 MIP simplex iterations
# 142 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 463 MIP simplex iterations
# 153 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 2381 MIP simplex iterations
# 954 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 8185 MIP simplex iterations
# 3877 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 9259 MIP simplex iterations
# 3729 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 1034 MIP simplex iterations
# 391 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 3277 MIP simplex iterations
# 1173 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 9715 MIP simplex iterations
# 3397 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 924 MIP simplex iterations
# 301 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 519 MIP simplex iterations
# 148 branch-and-bound nodes
# =========================(5, 20)LN=========================
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14.84358216
# 717189 MIP simplex iterations
# 112130 branch-and-bound nodes
# absmipgap = 0.00140405, relmipgap = 9.45894e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.09513191
# 67122 MIP simplex iterations
# 9543 branch-and-bound nodes
# absmipgap = 0.000938039, relmipgap = 5.82809e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.20101394
# 3056164 MIP simplex iterations
# 311330 branch-and-bound nodes
# absmipgap = 0.0017085, relmipgap = 9.38684e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15.96933071
# 2227065 MIP simplex iterations
# 367157 branch-and-bound nodes
# absmipgap = 0.00144097, relmipgap = 9.02338e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.3137085
# 1241507 MIP simplex iterations
# 157754 branch-and-bound nodes
# absmipgap = 0.00146078, relmipgap = 8.95429e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 19.05557051
# 40080 MIP simplex iterations
# 6598 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15.94260333
# 83030 MIP simplex iterations
# 13568 branch-and-bound nodes
# absmipgap = 0.00111949, relmipgap = 7.02201e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.164414
# 139433 MIP simplex iterations
# 15722 branch-and-bound nodes
# absmipgap = 0.000214711, relmipgap = 1.12036e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.37134606
# 685209 MIP simplex iterations
# 101312 branch-and-bound nodes
# absmipgap = 0.00157441, relmipgap = 9.61689e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 17.57624509
# 16320 MIP simplex iterations
# 2649 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.74456265
# 1905188 MIP simplex iterations
# 263624 branch-and-bound nodes
# absmipgap = 0.00184126, relmipgap = 9.82292e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.57816151
# 65275 MIP simplex iterations
# 10471 branch-and-bound nodes
# absmipgap = 0.000438676, relmipgap = 2.49558e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.79248266
# 343107 MIP simplex iterations
# 34465 branch-and-bound nodes
# absmipgap = 0.00175944, relmipgap = 9.36244e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.90435636
# 268397 MIP simplex iterations
# 25012 branch-and-bound nodes
# absmipgap = 0.00156369, relmipgap = 9.25022e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 17.29090601
# 15363 MIP simplex iterations
# 3150 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 13.91176256
# 574 MIP simplex iterations
# 99 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.4403823
# 94159 MIP simplex iterations
# 13765 branch-and-bound nodes
# absmipgap = 6.93185e-05, relmipgap = 3.75906e-06
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14.03207596
# 89172 MIP simplex iterations
# 13294 branch-and-bound nodes
# absmipgap = 0.000981545, relmipgap = 6.99501e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15.9559801
# 2050088 MIP simplex iterations
# 251080 branch-and-bound nodes
# absmipgap = 0.00158931, relmipgap = 9.96056e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.03450821
# 3622831 MIP simplex iterations
# 483804 branch-and-bound nodes
# absmipgap = 0.00157975, relmipgap = 9.8522e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15.66828838
# 45333 MIP simplex iterations
# 14773 branch-and-bound nodes
# absmipgap = 0.00126284, relmipgap = 8.05982e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14.06413088
# 73052 MIP simplex iterations
# 8135 branch-and-bound nodes
# absmipgap = 0.000469689, relmipgap = 3.33962e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.48588677
# 1567659 MIP simplex iterations
# 212340 branch-and-bound nodes
# absmipgap = 0.00168691, relmipgap = 9.64728e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.23236879
# 757402 MIP simplex iterations
# 112837 branch-and-bound nodes
# absmipgap = 0.00148232, relmipgap = 8.60193e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.37472545
# 4995767 MIP simplex iterations
# 807886 branch-and-bound nodes
# absmipgap = 0.00172679, relmipgap = 9.93851e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 16.52914229
# 59648 MIP simplex iterations
# 7757 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.98334393
# 87725 MIP simplex iterations
# 7854 branch-and-bound nodes
# absmipgap = 0.00184353, relmipgap = 9.71129e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.20556076
# 207071 MIP simplex iterations
# 16709 branch-and-bound nodes
# absmipgap = 0.00138171, relmipgap = 7.19432e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.56350323
# 177315 MIP simplex iterations
# 20244 branch-and-bound nodes
# absmipgap = 0.00171764, relmipgap = 9.7796e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.1406984
# 558463 MIP simplex iterations
# 73051 branch-and-bound nodes
# absmipgap = 0.00159663, relmipgap = 9.31486e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 18.06710288
# 58533 MIP simplex iterations
# 6603 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.62033063
# 242522 MIP simplex iterations
# 25180 branch-and-bound nodes
# absmipgap = 0.00175388, relmipgap = 8.93909e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 19.82308098
# 106209 MIP simplex iterations
# 15873 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.6740791
# 45893 MIP simplex iterations
# 6240 branch-and-bound nodes
# absmipgap = 0.00159848, relmipgap = 9.04418e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.07106781
# 24941 MIP simplex iterations
# 6338 branch-and-bound nodes
# absmipgap = 0.00156527, relmipgap = 9.73967e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.04656382
# 511728 MIP simplex iterations
# 46573 branch-and-bound nodes
# absmipgap = 0.00127411, relmipgap = 7.06015e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 16.28863069
# 30305 MIP simplex iterations
# 5132 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.57672221
# 867957 MIP simplex iterations
# 124207 branch-and-bound nodes
# absmipgap = 0.00171747, relmipgap = 9.77128e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.46248271
# 108347 MIP simplex iterations
# 11965 branch-and-bound nodes
# absmipgap = 0.000779286, relmipgap = 4.46263e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15.78828904
# 196506 MIP simplex iterations
# 24653 branch-and-bound nodes
# absmipgap = 0.000213323, relmipgap = 1.35115e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 18.44423377
# 29093 MIP simplex iterations
# 4819 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.36690682
# 2010888 MIP simplex iterations
# 334051 branch-and-bound nodes
# absmipgap = 0.00163354, relmipgap = 9.98076e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.87126283
# 8612645 MIP simplex iterations
# 1379159 branch-and-bound nodes
# absmipgap = 0.00165453, relmipgap = 9.8068e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.61972726
# 150402 MIP simplex iterations
# 18963 branch-and-bound nodes
# absmipgap = 0.00123062, relmipgap = 7.40458e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 14.78589116
# 5567 MIP simplex iterations
# 1111 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.39330536
# 2528561 MIP simplex iterations
# 294966 branch-and-bound nodes
# absmipgap = 0.00166452, relmipgap = 9.56986e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.13177877
# 276236 MIP simplex iterations
# 30267 branch-and-bound nodes
# absmipgap = 0.0016179, relmipgap = 8.923e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.99884231
# 950336 MIP simplex iterations
# 133516 branch-and-bound nodes
# absmipgap = 0.000428729, relmipgap = 2.52211e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.45863514
# 5333934 MIP simplex iterations
# 668391 branch-and-bound nodes
# absmipgap = 0.0017312, relmipgap = 9.91601e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.12105573
# 76667 MIP simplex iterations
# 8777 branch-and-bound nodes
# absmipgap = 0.00138346, relmipgap = 7.63457e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 14.3630811
# 18139 MIP simplex iterations
# 5306 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.9301262
# 90262 MIP simplex iterations
# 15885 branch-and-bound nodes
# absmipgap = 0.00138394, relmipgap = 8.17441e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.06183224
# 2483112 MIP simplex iterations
# 352626 branch-and-bound nodes
# absmipgap = 0.00154152, relmipgap = 9.59741e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.59756932
# 886909 MIP simplex iterations
# 149440 branch-and-bound nodes
# absmipgap = 0.00164434, relmipgap = 9.9071e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.22178822
# 66197 MIP simplex iterations
# 11039 branch-and-bound nodes
# absmipgap = 0.00170372, relmipgap = 9.8928e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.48780614
# 3296823 MIP simplex iterations
# 444792 branch-and-bound nodes
# absmipgap = 0.00172109, relmipgap = 9.84166e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.31992122
# 612322 MIP simplex iterations
# 58556 branch-and-bound nodes
# absmipgap = 0.000767584, relmipgap = 4.18989e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.65569656
# 8683168 MIP simplex iterations
# 1268616 branch-and-bound nodes
# absmipgap = 0.00173853, relmipgap = 9.84686e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.55771936
# 2202680 MIP simplex iterations
# 297208 branch-and-bound nodes
# absmipgap = 0.00171486, relmipgap = 9.76701e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 14.2093976
# 24418 MIP simplex iterations
# 6901 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.93759229
# 937629 MIP simplex iterations
# 146928 branch-and-bound nodes
# absmipgap = 0.00147151, relmipgap = 8.68786e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.8017809
# 476576 MIP simplex iterations
# 51996 branch-and-bound nodes
# absmipgap = 0.00193533, relmipgap = 9.77349e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.12428283
# 85450 MIP simplex iterations
# 10251 branch-and-bound nodes
# absmipgap = 0.00161182, relmipgap = 9.41246e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.29517194
# 2897590 MIP simplex iterations
# 429990 branch-and-bound nodes
# absmipgap = 0.00158873, relmipgap = 9.74969e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 16.48693205
# 53516 MIP simplex iterations
# 8295 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.53210017
# 256244 MIP simplex iterations
# 27122 branch-and-bound nodes
# absmipgap = 0.000964927, relmipgap = 5.50377e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14.40699561
# 14390 MIP simplex iterations
# 4301 branch-and-bound nodes
# absmipgap = 0.000726994, relmipgap = 5.04612e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 13.7440466
# 7899 MIP simplex iterations
# 2682 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.22674001
# 1842828 MIP simplex iterations
# 280525 branch-and-bound nodes
# absmipgap = 0.00169416, relmipgap = 9.83448e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.31331229
# 236944 MIP simplex iterations
# 29114 branch-and-bound nodes
# absmipgap = 0.00126394, relmipgap = 7.3004e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.59968009
# 460847 MIP simplex iterations
# 39489 branch-and-bound nodes
# absmipgap = 0.00156903, relmipgap = 9.45217e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.61046815
# 3153575 MIP simplex iterations
# 449747 branch-and-bound nodes
# absmipgap = 0.00156973, relmipgap = 8.91364e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.41794064
# 483789 MIP simplex iterations
# 59579 branch-and-bound nodes
# absmipgap = 0.00136061, relmipgap = 8.28731e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14.89795402
# 9726 MIP simplex iterations
# 2681 branch-and-bound nodes
# absmipgap = 0.0012603, relmipgap = 8.45955e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.42807019
# 461692 MIP simplex iterations
# 66511 branch-and-bound nodes
# absmipgap = 0.00158296, relmipgap = 9.6357e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.48361802
# 4298145 MIP simplex iterations
# 541487 branch-and-bound nodes
# absmipgap = 0.00170525, relmipgap = 9.22574e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 18.59906797
# 68900 MIP simplex iterations
# 8098 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.4385456
# 421006 MIP simplex iterations
# 45862 branch-and-bound nodes
# absmipgap = 0.00120791, relmipgap = 6.214e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.90897665
# 150749 MIP simplex iterations
# 15615 branch-and-bound nodes
# absmipgap = 0.00159376, relmipgap = 8.89921e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.28686852
# 178234 MIP simplex iterations
# 18077 branch-and-bound nodes
# absmipgap = 0.00149261, relmipgap = 8.63434e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.40013589
# 3453927 MIP simplex iterations
# ...
# 24308 MIP simplex iterations
# 2984 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 5917 MIP simplex iterations
# 855 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 1074 MIP simplex iterations
# 180 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 10093 MIP simplex iterations
# 1300 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 19901 MIP simplex iterations
# 2121 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 105
# 12098 MIP simplex iterations
# 1849 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 4572 MIP simplex iterations
# 701 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 2170 MIP simplex iterations
# 189 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81
# 7921 MIP simplex iterations
# 1243 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 20178 MIP simplex iterations
# 1869 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 24456 MIP simplex iterations
# 3252 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 9107 MIP simplex iterations
# 1201 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 22830 MIP simplex iterations
# 2979 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 3227 MIP simplex iterations
# 439 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 12652 MIP simplex iterations
# 1366 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 9673 MIP simplex iterations
# 1339 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 18362 MIP simplex iterations
# 2210 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 13910 MIP simplex iterations
# 2183 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 27771 MIP simplex iterations
# 3349 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 2859 MIP simplex iterations
# 518 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 2595 MIP simplex iterations
# 329 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 4716 MIP simplex iterations
# 724 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 12415 MIP simplex iterations
# 1337 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 6123 MIP simplex iterations
# 791 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 116
# 48967 MIP simplex iterations
# 5683 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 38185 MIP simplex iterations
# 6868 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 105
# 24139 MIP simplex iterations
# 2281 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 10014 MIP simplex iterations
# 1305 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 25105 MIP simplex iterations
# 3407 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 20916 MIP simplex iterations
# 2222 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 6434 MIP simplex iterations
# 1006 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 31129 MIP simplex iterations
# 3812 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 4921 MIP simplex iterations
# 707 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 25185 MIP simplex iterations
# 3029 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 66
# 826 MIP simplex iterations
# 62 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 10059 MIP simplex iterations
# 1082 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 18341 MIP simplex iterations
# 2351 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 10050 MIP simplex iterations
# 1726 branch-and-bound nodes
# =========================(5, 20)RT=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 762 MIP simplex iterations
# 145 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 1501 MIP simplex iterations
# 461 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 1281 MIP simplex iterations
# 523 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 1895 MIP simplex iterations
# 483 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 15704 MIP simplex iterations
# 7138 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 770 MIP simplex iterations
# 154 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 120
# 126 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 701 MIP simplex iterations
# 128 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 574 MIP simplex iterations
# 118 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 143 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 2109 MIP simplex iterations
# 740 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 130
# 14851 MIP simplex iterations
# 5126 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 1235 MIP simplex iterations
# 406 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 6452 MIP simplex iterations
# 2764 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 120 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 134
# 2289 MIP simplex iterations
# 622 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 1635 MIP simplex iterations
# 594 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 663 MIP simplex iterations
# 155 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 158 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 134 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 157 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 616 MIP simplex iterations
# 136 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 108 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 122
# 4853 MIP simplex iterations
# 2441 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 170 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 113
# 10667 MIP simplex iterations
# 5905 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 372 MIP simplex iterations
# 118 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 122 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 818 MIP simplex iterations
# 172 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 665 MIP simplex iterations
# 133 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 126 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 1613 MIP simplex iterations
# 631 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 2016 MIP simplex iterations
# 786 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 1323 MIP simplex iterations
# 466 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 74
# 147 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 113 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 116
# 3577 MIP simplex iterations
# 989 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 609 MIP simplex iterations
# 115 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 112
# 8542 MIP simplex iterations
# 2995 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 2029 MIP simplex iterations
# 763 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 2076 MIP simplex iterations
# 696 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 151 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 68895 MIP simplex iterations
# 31646 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 92 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 85 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 110 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 185 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 6498 MIP simplex iterations
# 3132 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 1804 MIP simplex iterations
# 628 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 427 MIP simplex iterations
# 136 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 172 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 72
# 667 MIP simplex iterations
# 147 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 2306 MIP simplex iterations
# 554 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 96 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 588 MIP simplex iterations
# 163 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 475 MIP simplex iterations
# 87 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 13389 MIP simplex iterations
# 8072 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 113
# 689 MIP simplex iterations
# 162 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 61
# 122 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 1883 MIP simplex iterations
# 715 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 4744 MIP simplex iterations
# 2605 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 91 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 1626 MIP simplex iterations
# 358 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 112
# 5462 MIP simplex iterations
# 2186 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 701 MIP simplex iterations
# 126 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 115
# 676 MIP simplex iterations
# 129 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 1327 MIP simplex iterations
# 588 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 2061 MIP simplex iterations
# 512 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 677 MIP simplex iterations
# 115 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 156 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 118
# 1296 MIP simplex iterations
# 501 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 156 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 1940 MIP simplex iterations
# 781 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 1114 MIP simplex iterations
# 400 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 71
# 1308 MIP simplex iterations
# 613 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 2092 MIP simplex iterations
# 740 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 124
# 6042 MIP simplex iterations
# 2098 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 1982 MIP simplex iterations
# 796 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 661 MIP simplex iterations
# 105 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 123
# 1192 MIP simplex iterations
# 319 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 2667 MIP simplex iterations
# 974 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 1151 MIP simplex iterations
# 253 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 120
# 591 MIP simplex iterations
# 152 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 85 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 672 MIP simplex iterations
# 130 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 77
# 473 MIP simplex iterations
# 78 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 6230 MIP simplex iterations
# 2562 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 1825 MIP simplex iterations
# 802 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 3466 MIP simplex iterations
# 1511 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 113
# 1206 MIP simplex iterations
# 400 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 2234 MIP simplex iterations
# 942 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 590 MIP simplex iterations
# 102 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 2973 MIP simplex iterations
# 983 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 56 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 3768 MIP simplex iterations
# 1639 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 123 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 753 MIP simplex iterations
# 147 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 697 MIP simplex iterations
# 133 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 113
# 146 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 1386 MIP simplex iterations
# 371 branch-and-bound nodes
# =========================(5, 20)RN=========================
# [97.489999999999995, 73.019999999999996, 101.58, 16.962333686708327, 14.391905558810866, 18.809277630307108, 3230.8800000000001, 2576.6999999999998, 3439.7399999999998, 98.920000000000002, 90.489999999999995, 99.019999999999996]
# [93.140000000000001, 70.269999999999996, 99.549999999999997, 17.056003857961361, 12.726122513881638, 17.966962538933846, 3165.21, 2560.2399999999998, 3394.9000000000001, 66.340000000000003, 48.119999999999997, 103.84]
# [0.95538003897835677,
#  0.96233908518214184,
#  0.98001575113211259,
#  1.005522245522527,
#  0.88425556031324715,
#  0.95521810523887152,
#  0.97967426831080073,
#  0.99361198432103082,
#  0.98696413100990199,
#  0.67064294379296407,
#  0.53177146646038231,
#  1.0486770349424359]

# %%
MinBenefit_ijk_sn_ratio = list(map(lambda a, b: a / b, MinBenefit_ijk_sn_2, MinBenefit_ijk_sn_1))
MinBenefit_ijk_sn_ratio
# Out:
# [0.95538003897835677,
#  0.96233908518214184,
#  0.98001575113211259,
#  1.005522245522527,
#  0.88425556031324715,
#  0.95521810523887152,
#  0.97967426831080073,
#  0.99361198432103082,
#  0.98696413100990199,
#  0.67064294379296407,
#  0.53177146646038231,
#  1.0486770349424359]

# %%
MinBenefit_ijk_sn_backup = [99.989999999999995, 98.719999999999999, 74.849999999999994, 3247.8899999999999, 3297.1700000000001, 2554.9499999999998, 18.810095335858538, 17.171713665074098, 14.211732444799729, 99.239999999999995, 96.549999999999997, 91.219999999999999]

# %% [markdown]
# ## Other Function

# %%
# Increase the costs of beef and ham

cost = ampl.getParameter('cost')
cost.setValues({'BEEF': 5.01, 'HAM': 4.55})
print("Increased costs of beef and ham.")

# 再解一次

ampl.solve()
print("New objective value:", totalcost.value())

# 印出其中項目

Buy = ampl.getVariable('Buy')
print("Buy['BEEF'].val = {}".format(Buy['BEEF'].value()))

# Display the dual value of each constraint

diet = ampl.getConstraint('diet')
for nutr in nutrients:
    print("diet['{}'].dual = {}".format(nutr, diet[nutr].dual()))
# Out:
# Increased costs of beef and ham.
# CPLEX 12.8.0.0: optimal solution; objective 144.0120033
# 0 simplex iterations (0 in phase I)
# New objective value: 144.01200332502074
# Buy['BEEF'].val = 5.226932668329172
# diet['A'].dual = 0.0
# diet['C'].dual = 0.0
# diet['B1'].dual = 0.0
# diet['B2'].dual = 0.7999285120532
# diet['NA'].dual = -0.007531172069825434
# diet['CAL'].dual = 0.0
