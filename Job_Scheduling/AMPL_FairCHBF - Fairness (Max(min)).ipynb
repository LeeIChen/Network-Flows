# %%
# Reference : https://ampl.com/api/extra/python_quickstart.html

# %% [markdown]
# ## Step 1: Path Setting

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import random
from operator import add

# %%
from bokeh.layouts import row
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e1168243-b030-4d90-9be5-6d66cb278741">Loading BokehJS ...</span>
#     </div>

# %%
from amplpy import AMPL, Environment, DataFrame

# %% [markdown]
# ## Step 2: Create an AMPL object

# %%
ampl = AMPL(Environment('C:\\Users\\user\\Desktop\\OR_Kung\\AMPL'))

# %% [markdown]
# ## Step 3: Select the solver

# %%
ampl.setOption('solver','C:\\Users\\user\\Desktop\\OR_Kung\\AMPL\\cplex')  #'gurobi'

# %% [markdown]
# ## Step 4: Define the model

# %%
# ampl.read('FairCHBF.mod')

# %%
ampl.eval('''
set I;
set J;

param B {J} >=0;   # benefit of doing the job
param C {J} >=0;   # cost of doing the job
param K {I} >=0;   # capacity of machine 

var X {I,J} >=0 binary;   # Decision var 1 # 其他問題寫"integer"
var MinBnft;              # Decision var 2

maximize Benefit: MinBnft;

s.t. Capacity {i in I        }: sum {j in J} C[j] * X[i,j] <= K[i];
s.t. ProdTime {        j in J}: sum {i in I}        X[i,j] <= 1;
s.t. MacBnft  {i in I        }: sum {j in J} B[j] * X[i,j] >= MinBnft;
s.t. Arrange  {i in I, j in J}:                     X[i,j] >= 0;

s.t. MinBenefit : MinBnft >=0;
''')

# %% [markdown]
# ## Step 5: Define the initial data

# %%
# batch 要做成:
# [ num_machine, num_job, cost, benefit, capacity ]

it_n = 100

def batch (num_machine, num_job, relation_bc, capacity):
    
    m = num_machine
    n = num_job
    
    list_c1 = []    # 內含 100組 n個 job的 cost 組合
    list_b1 = []    # 內含 100組 n個 job的 bnft 組合
    list_k1 = []    # 內含 100組 由 n個 job 加總算出的 k
    
    for i in range(it_n):
        
        list_c2 = []   # 內含 n個 job的 cost
        list_b2 = []   # 內含 n個 job的 bnft
        
        for j in range(n):
            c = int(random.randint(0,50))
            list_c2.append(c)

            if   relation_bc == 'L':
                b = c

            elif relation_bc == 'X':
                b = c**2

            elif relation_bc == 'A':
                b = c**(1/2)

            elif relation_bc == 'R':
                b = random.randint(0,50)  
            list_b2.append(b)

        if   capacity =='N':
            k = 10000 # no capacity

        elif capacity =='L':
            k = sum(list_c2) / m

        elif capacity =='T':
            k = sum(list_c2) * (0.75) / m
    
        list_c1.append(list_c2)
        list_b1.append(list_b2)
        list_k1.append(k)
    
    return  m, n, list_c1, list_b1, list_k1

# %%
# Test OK! 不要在正式 run 100組時  print，會很慢 >"<
'''
instance = batch( 5, 20, 'A', 'T' )
print(instance[2])
print(instance[3])
'''
# Out:
# [[22, 48, 34, 16, 40, 30, 5, 48, 34, 17, 18, 5, 41, 26, 14, 12, 26, 45, 15, 35], [43, 35, 6, 18, 16, 31, 9, 8, 12, 35, 13, 23, 50, 48, 30, 48, 50, 35, 25, 29]]
# [[4.69041575982343, 6.928203230275509, 5.830951894845301, 4.0, 6.324555320336759, 5.477225575051661, 2.23606797749979, 6.928203230275509, 5.830951894845301, 4.123105625617661, 4.242640687119285, 2.23606797749979, 6.4031242374328485, 5.0990195135927845, 3.7416573867739413, 3.4641016151377544, 5.0990195135927845, 6.708203932499369, 3.872983346207417, 5.916079783099616], [6.557438524302, 5.916079783099616, 2.449489742783178, 4.242640687119285, 4.0, 5.5677643628300215, 3.0, 2.8284271247461903, 3.4641016151377544, 5.916079783099616, 3.605551275463989, 4.795831523312719, 7.0710678118654755, 6.928203230275509, 5.477225575051661, 6.928203230275509, 7.0710678118654755, 5.916079783099616, 5.0, 5.385164807134504]]

# %%
machine_job  = [(5,20)]
capacity     = ['L','T','N']
relation_bc  = ['L','A','X','R']

# %% [markdown]
# ## Step 6: Model Build-up & Solution

# %%
# 迭代 instance

MinBenefit_ijk_sn_1 = []
MinBenefit_ijk_sn_2 = []

for i in machine_job:
    
    num_machine = i[0]
    num_job     = i[1]

    # 印出編號，但從1開始算而不是從0，再讓 [1,2,3] -> [M1,M2,M3]

    machine1 = ['M']*num_machine
    job1     = ['J']*num_job
    machine2 = map(add, list(range(num_machine)), [1]*num_machine)
    job2     = map(add, list(range(num_job))    , [1]*num_job)
    machine2 = list( str(x) for x in machine2 )
    job2     = list( str(x) for x in job2     )
    machine  = list (map(lambda y, z: y + z, machine1, machine2))
    job      = list (map(lambda y, z: y + z, job1,     job2    ))

    # AMPL sets

    ampl.getSet('I').setValues(machine)
    ampl.getSet('J').setValues(job)
    
    for k in capacity:    
        for j in relation_bc:

            instance = batch( i[0], i[1], j, k )
                       
            MinBenefit_1 = []
            MinBenefit_2 = []
            
            for p in range(it_n):      
                
                # ====== Model 1 ======= : 一組一組用solver算 IP (or linear relaxed LP)，每種senario要算 100組 再平均
                
                # amplpy DataFrame
                ampl.setData(DataFrame(
                index=[('J', job)], 
                columns=[
                    ('B', instance[3][p]), 
                    ('C', instance[2][p])
                ]
                ))

                # Pandas DataFrame
                df = pd.DataFrame({
                    'K': [ instance[4][p] ]*num_machine
                }, 
                    index = machine
                )
                ampl.setData(DataFrame.fromPandas(df))

                # Solve the problem
                ampl.solve()

                '''
                # Create a DataFrame with Decision variables
                Var = ampl.getVariable('X').getValues().toPandas()
                print(Var)
                '''

                # Display the objective value
                MinBnft_1 = ampl.getObjective('Benefit')
                MinBnft_1 = MinBnft_1.value()
                MinBenefit_1 = np.append(MinBenefit_1, MinBnft_1) # numpy.ndarray
                
                
                # ====== Model 2 ======= : 一組一組用 CHBF算，每種senario要算 100組 再平均
                
                # 將 job 按照 cost (workload) 排序

                list_c = instance[2][p]
                list_b = instance[3][p]

                list_cb = list(zip(list_c, list_b))        # [3,5]  [8,1]  -> [(3,8),(5,1)]
                s_cb    = sorted(list_cb, reverse = True)  # [(3,8),(5,1)] -> [(5,1),(3,8)]
                o_cb    = list(zip(*s_cb))                 # [(5,1),(3,8)] -> [(5,3),(1,8)]

                list_c  = list(o_cb[0])                    # [5,3]
                list_b  = list(o_cb[1])                    # [1,8]

                mach = []                 # machine
                ca = instance[4][p]

                for r in range(num_machine):

                    mach.append([])    # machine set中安排一台台 machine 被 append 進來
                    mach[r].append(0)  # 初始的 benefit和 是 0
                    mach[r].append(ca) # 初始的 capacity  是 ca

                for s in range(num_job):

                    mach = sorted(mach)                           # 按照 benefit和 由小而大排序
                    # print(machine)

                    for r in range(num_machine):                  # 由最小 benefit和 的先開始

                        if list_c[s] <= mach[r][1]:               # machine r 還有 capacity 餘裕

                            # print(mach[r])
                            mach[r][1] -= list_c[s]
                            mach[r][0] += list_b[s]
                            # print(mach[r])
                            # print('=================')
                            break
                
                mach = sorted(mach)                               # 再一次 按照 benefit和 由小而大排序
                MinBnft_2 = mach[0][0]                            # 將最小的 benefit和的 machine 取出來
                MinBenefit_2 = np.append(MinBenefit_2, MinBnft_2) # numpy.ndarray
                
                
            # ====== Model 1 Objective value: ====== #
            
            list_M1          = list(MinBenefit_1)
            MinBenefit_100_1 = sum(list_M1) / len(list_M1)
            MinBenefit_ijk_sn_1.append(MinBenefit_100_1)   # i*j*k 種 senario 迭代
            
            # ====== Model 2 Objective value: ====== #
            
            list_M2         = list(MinBenefit_2)
            MinBenefit_100_2 = sum(list_M2) / len(list_M2)
            MinBenefit_ijk_sn_2.append(MinBenefit_100_2)   # i*j*k 種 senario 迭代
            
            print('=========================' + str(i) + str(j) + str(k) + '=========================') # 分隔           
            
print(MinBenefit_ijk_sn_1) # list
print(MinBenefit_ijk_sn_2) # list

MinBenefit_ijk_sn_ratio = list(map(lambda a, b: a / b, MinBenefit_ijk_sn_2, MinBenefit_ijk_sn_1))
MinBenefit_ijk_sn_ratio
# Out:
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 286 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 41407 MIP simplex iterations
# 6616 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 180 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 120
# 6376 MIP simplex iterations
# 1510 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 807 MIP simplex iterations
# 114 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 126
# 5336 MIP simplex iterations
# 1041 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 417 MIP simplex iterations
# 115 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 120643 MIP simplex iterations
# 16528 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 115
# 57805 MIP simplex iterations
# 10238 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 21488 MIP simplex iterations
# 2240 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81
# 714 MIP simplex iterations
# 102 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 35998 MIP simplex iterations
# 6387 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 42536 MIP simplex iterations
# 6380 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 266241 MIP simplex iterations
# 17576 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 212 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 45377 MIP simplex iterations
# 7949 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 35066 MIP simplex iterations
# 6786 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 130 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 1755 MIP simplex iterations
# 387 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 161879 MIP simplex iterations
# 18125 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 80718 MIP simplex iterations
# 9186 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 35252 MIP simplex iterations
# 6554 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 52273 MIP simplex iterations
# 6258 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 346905 MIP simplex iterations
# 26596 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 651 MIP simplex iterations
# 76 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 19708 MIP simplex iterations
# 2069 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 31053 MIP simplex iterations
# 5058 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 2057 MIP simplex iterations
# 418 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 256088 MIP simplex iterations
# 30030 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75
# 769 MIP simplex iterations
# 105 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 989 MIP simplex iterations
# 202 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 206874 MIP simplex iterations
# 22122 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 194398 MIP simplex iterations
# 19433 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 237 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 74
# 143 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 237 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 34609 MIP simplex iterations
# 6388 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 40093 MIP simplex iterations
# 6635 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 1838 MIP simplex iterations
# 438 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 125221 MIP simplex iterations
# 16073 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 126
# 113006 MIP simplex iterations
# 10555 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 36539 MIP simplex iterations
# 7524 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 6295 MIP simplex iterations
# 829 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 127 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 38179 MIP simplex iterations
# 4546 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 2412 MIP simplex iterations
# 568 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 1118454 MIP simplex iterations
# 126103 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 576 MIP simplex iterations
# 123 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 39178 MIP simplex iterations
# 6277 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 225 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 11710 MIP simplex iterations
# 1946 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 225 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 71
# 176 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 1390618 MIP simplex iterations
# 155311 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 151 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 210 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 139197 MIP simplex iterations
# 15819 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 126
# 1702 MIP simplex iterations
# 357 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 679 MIP simplex iterations
# 87 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 14177 MIP simplex iterations
# 2078 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 184 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 30092 MIP simplex iterations
# 3492 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 73
# 33205 MIP simplex iterations
# 6641 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 122
# 3106 MIP simplex iterations
# 773 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 44187 MIP simplex iterations
# 6221 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 43986 MIP simplex iterations
# 4419 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 124300 MIP simplex iterations
# 16222 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 38654 MIP simplex iterations
# 7603 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 3280 MIP simplex iterations
# 814 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 266 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 699 MIP simplex iterations
# 93 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 192 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 115
# 38320 MIP simplex iterations
# 6440 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 97787 MIP simplex iterations
# 9750 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 76
# 170 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 186 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 3742 MIP simplex iterations
# 757 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 7638 MIP simplex iterations
# 1892 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 33947 MIP simplex iterations
# 7035 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 131 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 105
# 282 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 7171 MIP simplex iterations
# 1671 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 40601 MIP simplex iterations
# 6661 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 121
# 2955 MIP simplex iterations
# 731 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 33648 MIP simplex iterations
# 6931 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 154037 MIP simplex iterations
# 16722 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 7125 MIP simplex iterations
# 1701 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 345296 MIP simplex iterations
# 28217 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 112
# 5933 MIP simplex iterations
# 1648 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 164349 MIP simplex iterations
# 12824 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 47935 MIP simplex iterations
# 5834 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 145
# 107662 MIP simplex iterations
# 9646 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 267 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 89762 MIP simplex iterations
# 11736 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 142 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 11963 MIP simplex iterations
# 2709 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 120301 MIP simplex iterations
# 12239 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 92920 MIP simplex iterations
# 11002 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 78
# 128 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 6304 MIP simplex iterations
# 1862 branch-and-bound nodes
# =========================(5, 20)LL=========================
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 21.56239445
# 123021 MIP simplex iterations
# 12554 branch-and-bound nodes
# absmipgap = 0.00133267, relmipgap = 6.18051e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.03817922
# 208464 MIP simplex iterations
# 20826 branch-and-bound nodes
# absmipgap = 0.00132162, relmipgap = 7.32682e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.57076557
# 1912492 MIP simplex iterations
# 272646 branch-and-bound nodes
# absmipgap = 0.00161621, relmipgap = 9.75337e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 17.83979601
# 56840 MIP simplex iterations
# 10115 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 15.94260167
# 306765 MIP simplex iterations
# 42743 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.34619605
# 2211176 MIP simplex iterations
# 319902 branch-and-bound nodes
# absmipgap = 0.00162535, relmipgap = 9.37008e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.96964488
# 660393 MIP simplex iterations
# 74135 branch-and-bound nodes
# absmipgap = 0.00172488, relmipgap = 8.63752e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.64181848
# 202034 MIP simplex iterations
# 26464 branch-and-bound nodes
# absmipgap = 0.000976422, relmipgap = 5.2378e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.20101394
# 26185 MIP simplex iterations
# 6137 branch-and-bound nodes
# absmipgap = 0.00107122, relmipgap = 6.61205e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.88034981
# 475994 MIP simplex iterations
# 59531 branch-and-bound nodes
# absmipgap = 0.00166415, relmipgap = 9.85849e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 15.27518455
# 86225 MIP simplex iterations
# 14726 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 19.32917291
# 63778 MIP simplex iterations
# 6891 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.51800129
# 2950864 MIP simplex iterations
# 310694 branch-and-bound nodes
# absmipgap = 0.00190708, relmipgap = 9.77087e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 15.61260013
# 3590 MIP simplex iterations
# 639 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.94071507
# 924511 MIP simplex iterations
# 101210 branch-and-bound nodes
# absmipgap = 0.00134336, relmipgap = 7.92975e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.25452673
# 189164 MIP simplex iterations
# 22592 branch-and-bound nodes
# absmipgap = 0.00169162, relmipgap = 9.80394e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15.90713102
# 72235 MIP simplex iterations
# 9763 branch-and-bound nodes
# absmipgap = 0.000874088, relmipgap = 5.49495e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.77166696
# 2293370 MIP simplex iterations
# 298589 branch-and-bound nodes
# absmipgap = 0.0016442, relmipgap = 9.80342e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.27574217
# 191023 MIP simplex iterations
# 28067 branch-and-bound nodes
# absmipgap = 0.0017821, relmipgap = 9.24531e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.40388593
# 1754690 MIP simplex iterations
# 216903 branch-and-bound nodes
# absmipgap = 0.00158584, relmipgap = 9.11201e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.55749247
# 220723 MIP simplex iterations
# 30347 branch-and-bound nodes
# absmipgap = 0.00171157, relmipgap = 9.22306e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.13295307
# 853686 MIP simplex iterations
# 100715 branch-and-bound nodes
# absmipgap = 0.00172599, relmipgap = 9.51855e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.28447373
# 1427926 MIP simplex iterations
# 221625 branch-and-bound nodes
# absmipgap = 0.00180819, relmipgap = 9.88921e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 18.04168927
# 28390 MIP simplex iterations
# 5452 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.29946113
# 291202 MIP simplex iterations
# 28503 branch-and-bound nodes
# absmipgap = 0.00127509, relmipgap = 7.82293e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 12.46198219
# 3697 MIP simplex iterations
# 936 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.77413713
# 561856 MIP simplex iterations
# 57017 branch-and-bound nodes
# absmipgap = 0.00163626, relmipgap = 9.75467e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.87388468
# 1885386 MIP simplex iterations
# 205702 branch-and-bound nodes
# absmipgap = 0.00172296, relmipgap = 9.1288e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.22874697
# 1313317 MIP simplex iterations
# 205337 branch-and-bound nodes
# absmipgap = 0.00153638, relmipgap = 9.46702e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 13.71476867
# 68363 MIP simplex iterations
# 17036 branch-and-bound nodes
# absmipgap = 0.000484158, relmipgap = 3.53019e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.1432789
# 1061967 MIP simplex iterations
# 160780 branch-and-bound nodes
# absmipgap = 0.00164588, relmipgap = 9.60073e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.09901951
# 277841 MIP simplex iterations
# 33273 branch-and-bound nodes
# absmipgap = 0.00138872, relmipgap = 8.12166e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 18.43116914
# 73339 MIP simplex iterations
# 6811 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.79333728
# 16782 MIP simplex iterations
# 4261 branch-and-bound nodes
# absmipgap = 0.000301403, relmipgap = 1.69391e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.21829126
# 123690 MIP simplex iterations
# 13861 branch-and-bound nodes
# absmipgap = 0.000903175, relmipgap = 5.24544e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.12105573
# 161676 MIP simplex iterations
# 21570 branch-and-bound nodes
# absmipgap = 0.00111033, relmipgap = 6.12728e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.95445115
# 352833 MIP simplex iterations
# 42096 branch-and-bound nodes
# absmipgap = 0.00145186, relmipgap = 8.08636e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.07339065
# 5812905 MIP simplex iterations
# 1176172 branch-and-bound nodes
# absmipgap = 0.00177177, relmipgap = 9.80319e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 13.71476867
# 159916 MIP simplex iterations
# 27029 branch-and-bound nodes
# absmipgap = 0.00111852, relmipgap = 8.1556e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14.94071507
# 71651 MIP simplex iterations
# 10245 branch-and-bound nodes
# absmipgap = 0.000413012, relmipgap = 2.76434e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.37199641
# 108213 MIP simplex iterations
# 10899 branch-and-bound nodes
# absmipgap = 0.000301107, relmipgap = 1.73329e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.71545125
# 2945999 MIP simplex iterations
# 410709 branch-and-bound nodes
# absmipgap = 0.00158685, relmipgap = 8.95743e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.00944852
# 1204501 MIP simplex iterations
# 191095 branch-and-bound nodes
# absmipgap = 0.00174067, relmipgap = 9.66529e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 16.09048089
# 42834 MIP simplex iterations
# 7122 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.73892082
# 475753 MIP simplex iterations
# 86725 branch-and-bound nodes
# absmipgap = 0.00147763, relmipgap = 8.82749e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.71285852
# 232029 MIP simplex iterations
# 24883 branch-and-bound nodes
# absmipgap = 0.00184548, relmipgap = 9.86208e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 13.55923352
# 2461 MIP simplex iterations
# 875 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.14397748
# 2631862 MIP simplex iterations
# 387736 branch-and-bound nodes
# absmipgap = 0.00167202, relmipgap = 9.75279e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.34330965
# 980689 MIP simplex iterations
# 141495 branch-and-bound nodes
# absmipgap = 0.00173006, relmipgap = 9.97537e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.47272464
# 2075345 MIP simplex iterations
# 370914 branch-and-bound nodes
# absmipgap = 0.00141421, relmipgap = 8.58516e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.68781417
# 1004985 MIP simplex iterations
# 110947 branch-and-bound nodes
# absmipgap = 0.00160036, relmipgap = 8.56364e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.19499474
# 3898271 MIP simplex iterations
# 862839 branch-and-bound nodes
# absmipgap = 0.00170689, relmipgap = 9.92667e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.63830336
# 465247 MIP simplex iterations
# 69966 branch-and-bound nodes
# absmipgap = 0.00133692, relmipgap = 7.57961e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.13686749
# 72260 MIP simplex iterations
# 9743 branch-and-bound nodes
# absmipgap = 0.000844838, relmipgap = 5.23545e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14.77196283
# 9494 MIP simplex iterations
# 2574 branch-and-bound nodes
# absmipgap = 0.00139392, relmipgap = 9.43627e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.29389201
# 109094 MIP simplex iterations
# 10863 branch-and-bound nodes
# absmipgap = 0.00128313, relmipgap = 7.01398e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.45570798
# 1152380 MIP simplex iterations
# 135956 branch-and-bound nodes
# absmipgap = 0.00160597, relmipgap = 9.20027e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.39647103
# 1960727 MIP simplex iterations
# 240547 branch-and-bound nodes
# absmipgap = 0.00153681, relmipgap = 8.83405e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.57188782
# 3203901 MIP simplex iterations
# 424612 branch-and-bound nodes
# absmipgap = 0.00146787, relmipgap = 8.3535e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 15.36845797
# 19579 MIP simplex iterations
# 4159 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18.57551454
# 55997 MIP simplex iterations
# 5878 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.75587376
# 97330 MIP simplex iterations
# 10445 branch-and-bound nodes
# absmipgap = 0.00136189, relmipgap = 8.12786e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.10229876
# 463276 MIP simplex iterations
# 74043 branch-and-bound nodes
# absmipgap = 0.000608529, relmipgap = 3.77915e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 16.47449403
# 18688 MIP simplex iterations
# 3586 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.9974174
# 26984 MIP simplex iterations
# 5541 branch-and-bound nodes
# absmipgap = 0.00104979, relmipgap = 6.17615e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.87494722
# 90335 MIP simplex iterations
# 8881 branch-and-bound nodes
# absmipgap = 0.00169061, relmipgap = 8.50624e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.97281209
# 260281 MIP simplex iterations
# 30846 branch-and-bound nodes
# absmipgap = 0.000381793, relmipgap = 2.24944e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.38516481
# 535034 MIP simplex iterations
# 60380 branch-and-bound nodes
# absmipgap = 0.00117538, relmipgap = 6.76083e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 13.85556715
# 424022 MIP simplex iterations
# 58621 branch-and-bound nodes
# absmipgap = 0.00114882, relmipgap = 8.29136e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.83989761
# 169629 MIP simplex iterations
# 18567 branch-and-bound nodes
# absmipgap = 0.00181738, relmipgap = 9.64646e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15.8721978
# 739719 MIP simplex iterations
# 115015 branch-and-bound nodes
# absmipgap = 0.00158015, relmipgap = 9.95548e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.28444902
# 115232 MIP simplex iterations
# 11904 branch-and-bound nodes
# absmipgap = 0.00128812, relmipgap = 7.45248e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.14768688
# 236041 MIP simplex iterations
# 23618 branch-and-bound nodes
# absmipgap = 0.00142716, relmipgap = 8.32276e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.03275925
# 48864 MIP simplex iterations
# 7197 branch-and-bound nodes
# absmipgap = 0.00158151, relmipgap = 8.3094e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 15.29142679
# 10345 MIP simplex iterations
# 2525 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.244998
# 440665 MIP simplex iterations
# 54538 branch-and-bound nodes
# absmipgap = 0.000310377, relmipgap = 1.61277e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.82732518
# 216400 MIP simplex iterations
# 26750 branch-and-bound nodes
# absmipgap = 7.97144e-05, relmipgap = 4.23397e-06
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19.46470385
# 417133 MIP simplex iterations
# 38557 branch-and-bound nodes
# absmipgap = 0.00179118, relmipgap = 9.20219e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.98568226
# 423044 MIP simplex iterations
# 46433 branch-and-bound nodes
# absmipgap = 0.00164202, relmipgap = 9.12959e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 17.2242224
# 64468 MIP simplex iterations
# 8642 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.47212072
# 2235231 MIP simplex iterations
# 309891 branch-and-bound nodes
# absmipgap = 0.00171919, relmipgap = 9.83964e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 18.9578049
# 282549 MIP simplex iterations
# 36148 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.45929077
# 84129 MIP simplex iterations
# 13576 branch-and-bound nodes
# absmipgap = 0.000870151, relmipgap = 4.71389e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.97863878
# 3811885 MIP simplex iterations
# 454678 branch-and-bound nodes
# absmipgap = 0.00178524, relmipgap = 9.92979e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15.97495689
# 157204 MIP simplex iterations
# 20145 branch-and-bound nodes
# absmipgap = 0.00129119, relmipgap = 8.08261e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.46961661
# 1001945 MIP simplex iterations
# 108590 branch-and-bound nodes
# absmipgap = 0.00153144, relmipgap = 8.76629e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 16.12194794
# 111438 MIP simplex iterations
# 12612 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.30124459
# 478786 MIP simplex iterations
# 60553 branch-and-bound nodes
# absmipgap = 0.00143011, relmipgap = 8.773e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 16.03163986
# 16774 MIP simplex iterations
# 4306 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.21300979
# 140163 MIP simplex iterations
# 22729 branch-and-bound nodes
# absmipgap = 0.00158697, relmipgap = 8.71336e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.06502803
# 886648 MIP simplex iterations
# 144602 branch-and-bound nodes
# absmipgap = 0.00129297, relmipgap = 7.15733e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 18.03131334
# 32981 MIP simplex iterations
# 4611 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15.98939067
# 553452 MIP simplex iterations
# 70011 branch-and-bound nodes
# absmipgap = 0.00153086, relmipgap = 9.57423e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17.1432789
# 542078 MIP simplex iterations
# 74635 branch-and-bound nodes
# absmipgap = 0.000733153, relmipgap = 4.27662e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.01954137
# 980615 MIP simplex iterations
# 176582 branch-and-bound nodes
# absmipgap = 0.00130457, relmipgap = 8.14365e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 17.43865984
# 32229 MIP simplex iterations
# 6077 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.63115785
# 878263 MIP simplex iterations
# 120446 branch-and-bound nodes
# absmipgap = 0.00147929, relmipgap = 8.89467e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.01761974
# 1392661 MIP simplex iterations
# 272427 branch-and-bound nodes
# absmipgap = 0.00139357, relmipgap = 8.70024e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 16.03208228
# 60773 MIP simplex iterations
# 10409 branch-and-bound nodes
# absmipgap = 0.000861906, relmipgap = 5.37613e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18.92704554
# 80577 MIP simplex iterations
# 9005 branch-and-bound nodes
# absmipgap = 0.000148919, relmipgap = 7.86807e-06
# =========================(5, 20)AL=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 4010
# 20189 MIP simplex iterations
# 2015 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2221
# 438 MIP simplex iterations
# 31 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3276
# 1454 MIP simplex iterations
# 182 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3590
# 12680 MIP simplex iterations
# 1686 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3706
# 3264 MIP simplex iterations
# 369 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2801
# 465 MIP simplex iterations
# 46 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3073
# 4259 MIP simplex iterations
# 511 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2171
# 1316 MIP simplex iterations
# 160 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3064
# 1234 MIP simplex iterations
# 138 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3482
# 11135 MIP simplex iterations
# 1232 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2274
# 545 MIP simplex iterations
# 20 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3146
# 1552 MIP simplex iterations
# 116 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2543
# 2286 MIP simplex iterations
# 342 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2659
# 544 MIP simplex iterations
# 34 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3929
# 15812 MIP simplex iterations
# 1852 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2538
# 476 MIP simplex iterations
# 64 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2417
# 698 MIP simplex iterations
# 40 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3788
# 7311 MIP simplex iterations
# 760 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3154
# 7254 MIP simplex iterations
# 785 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4599
# 25970 MIP simplex iterations
# 2385 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4014
# 17719 MIP simplex iterations
# 1908 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3597
# 2380 MIP simplex iterations
# 456 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2550
# 503 MIP simplex iterations
# 67 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3661
# 7424 MIP simplex iterations
# 1155 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3290
# 5996 MIP simplex iterations
# 777 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2774
# 254 MIP simplex iterations
# 14 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4062
# 3088 MIP simplex iterations
# 355 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4434
# 15130 MIP simplex iterations
# 1337 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3899
# 36886 MIP simplex iterations
# 3419 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3152
# 1789 MIP simplex iterations
# 252 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3408
# 2553 MIP simplex iterations
# 340 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3000
# 1297 MIP simplex iterations
# 120 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4049
# 5648 MIP simplex iterations
# 727 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2740
# 488 MIP simplex iterations
# 38 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3790
# 10156 MIP simplex iterations
# 1142 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4226
# 20344 MIP simplex iterations
# 2320 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3382
# 4842 MIP simplex iterations
# 596 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3210
# 460 MIP simplex iterations
# 11 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4629
# 27852 MIP simplex iterations
# 2370 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3825
# 4989 MIP simplex iterations
# 737 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3127
# 1617 MIP simplex iterations
# 195 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2725
# 906 MIP simplex iterations
# 149 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2996
# 3045 MIP simplex iterations
# 273 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3153
# 1813 MIP simplex iterations
# 298 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3380
# 1567 MIP simplex iterations
# 227 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2937
# 1266 MIP simplex iterations
# 105 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3550
# 12839 MIP simplex iterations
# 1167 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2635
# 593 MIP simplex iterations
# 23 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3492
# 5279 MIP simplex iterations
# 731 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2938
# 7016 MIP simplex iterations
# 771 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3609
# 3273 MIP simplex iterations
# 616 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2785
# 1600 MIP simplex iterations
# 382 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3490
# 14590 MIP simplex iterations
# 1597 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 5186
# 42229 MIP simplex iterations
# 3636 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4027
# 32303 MIP simplex iterations
# 3020 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3529
# 1459 MIP simplex iterations
# 257 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3230
# 2042 MIP simplex iterations
# 414 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3082
# 7402 MIP simplex iterations
# 972 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3572
# 1523 MIP simplex iterations
# 269 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4071
# 7274 MIP simplex iterations
# 874 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3123
# 983 MIP simplex iterations
# 47 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3590
# 1536 MIP simplex iterations
# 188 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3912
# 2341 MIP simplex iterations
# 354 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3657
# 7070 MIP simplex iterations
# 820 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3693
# 30511 MIP simplex iterations
# 2743 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3896
# 9654 MIP simplex iterations
# 1048 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3134
# 2811 MIP simplex iterations
# 383 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2258
# 412 MIP simplex iterations
# 9 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3295
# 2739 MIP simplex iterations
# 464 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2847
# 3974 MIP simplex iterations
# 484 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3288
# 6662 MIP simplex iterations
# 949 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4034
# 13721 MIP simplex iterations
# 1388 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2306
# 663 MIP simplex iterations
# 36 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2843
# 1003 MIP simplex iterations
# 71 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3442
# 1064 MIP simplex iterations
# 99 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3257
# 2157 MIP simplex iterations
# 197 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2951
# 2042 MIP simplex iterations
# 342 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3271
# 11551 MIP simplex iterations
# 1571 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3254
# 886 MIP simplex iterations
# 117 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2478
# 383 MIP simplex iterations
# 11 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3489
# 803 MIP simplex iterations
# 133 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3496
# 4506 MIP simplex iterations
# 501 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4444
# 4836 MIP simplex iterations
# 863 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3597
# 3848 MIP simplex iterations
# 527 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3418
# 27475 MIP simplex iterations
# 2234 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3028
# 1662 MIP simplex iterations
# 171 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3405
# 1859 MIP simplex iterations
# 276 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3934
# 13953 MIP simplex iterations
# 1774 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4102
# 8153 MIP simplex iterations
# 1115 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2626
# 752 MIP simplex iterations
# 74 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3648
# 11204 MIP simplex iterations
# 1335 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2886
# 2572 MIP simplex iterations
# 438 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 1754
# 537 MIP simplex iterations
# 28 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4654
# 41570 MIP simplex iterations
# 3669 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 1676
# 742 MIP simplex iterations
# 34 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2025
# 442 MIP simplex iterations
# 21 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4155
# 7645 MIP simplex iterations
# 858 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 1893
# 427 MIP simplex iterations
# 11 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4265
# 21480 MIP simplex iterations
# 2465 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3121
# 1318 MIP simplex iterations
# 105 branch-and-bound nodes
# =========================(5, 20)XL=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 179806 MIP simplex iterations
# 16235 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 76
# 24817 MIP simplex iterations
# 2362 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 87154 MIP simplex iterations
# 10715 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 2248 MIP simplex iterations
# 477 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 69
# 1823 MIP simplex iterations
# 373 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 77
# 44794 MIP simplex iterations
# 4816 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 91845 MIP simplex iterations
# 10212 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 37562 MIP simplex iterations
# 8427 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 39030 MIP simplex iterations
# 6348 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 389980 MIP simplex iterations
# 19428 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 12846 MIP simplex iterations
# 2335 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 41763 MIP simplex iterations
# 3169 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 118
# 51912 MIP simplex iterations
# 3504 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 115
# 36985 MIP simplex iterations
# 9236 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 16582 MIP simplex iterations
# 3219 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 41543 MIP simplex iterations
# 7002 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 51648 MIP simplex iterations
# 8086 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 171883 MIP simplex iterations
# 11076 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 8785 MIP simplex iterations
# 1892 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 65283 MIP simplex iterations
# 4384 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 124
# 139466 MIP simplex iterations
# 13263 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 75691 MIP simplex iterations
# 9285 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 51598 MIP simplex iterations
# 5793 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 78738 MIP simplex iterations
# 7373 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 50645 MIP simplex iterations
# 3477 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 74784 MIP simplex iterations
# 5275 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 63402 MIP simplex iterations
# 8531 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 38083 MIP simplex iterations
# 5968 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 27066 MIP simplex iterations
# 5117 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 29309 MIP simplex iterations
# 3131 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 254146 MIP simplex iterations
# 22264 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 86858 MIP simplex iterations
# 8862 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 129836 MIP simplex iterations
# 13067 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 9123 MIP simplex iterations
# 1860 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 11305 MIP simplex iterations
# 3061 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 46891 MIP simplex iterations
# 7403 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 1866 MIP simplex iterations
# 402 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 137
# 133303 MIP simplex iterations
# 11327 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 112
# 34198 MIP simplex iterations
# 6399 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 34286 MIP simplex iterations
# 4864 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 119145 MIP simplex iterations
# 9609 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 62688 MIP simplex iterations
# 5035 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 120
# 239501 MIP simplex iterations
# 13259 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 115
# 9050 MIP simplex iterations
# 1651 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 19735 MIP simplex iterations
# 3871 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 78097 MIP simplex iterations
# 6754 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 149511 MIP simplex iterations
# 13975 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 11369 MIP simplex iterations
# 2744 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 56445 MIP simplex iterations
# 7631 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 161066 MIP simplex iterations
# 14166 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 115
# 72711 MIP simplex iterations
# 7906 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 71
# 37424 MIP simplex iterations
# 3427 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 12871 MIP simplex iterations
# 2544 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 203855 MIP simplex iterations
# 17113 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 158 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88
# 11964 MIP simplex iterations
# 2205 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 125
# 105984 MIP simplex iterations
# 8836 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 18025 MIP simplex iterations
# 3604 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 4395 MIP simplex iterations
# 905 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 5249 MIP simplex iterations
# 1273 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 123
# 420944 MIP simplex iterations
# 32503 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 102553 MIP simplex iterations
# 8382 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 13010 MIP simplex iterations
# 2863 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 39970 MIP simplex iterations
# ...
# 635 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2157
# 16257 MIP simplex iterations
# 8908 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3830
# 87255 MIP simplex iterations
# 29609 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3295
# 6038 MIP simplex iterations
# 2623 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3462
# 2460 MIP simplex iterations
# 535 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2430
# 34160 MIP simplex iterations
# 22049 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3229
# 6374 MIP simplex iterations
# 2573 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4289
# 37255 MIP simplex iterations
# 16758 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3194
# 17482 MIP simplex iterations
# 7825 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2466
# 44349 MIP simplex iterations
# 17736 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3213
# 1935 MIP simplex iterations
# 804 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 5043
# 37457 MIP simplex iterations
# 9047 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4373
# 53577 MIP simplex iterations
# 16649 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2925
# 19524 MIP simplex iterations
# 9766 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2843
# 17333 MIP simplex iterations
# 8435 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2869
# 116650 MIP simplex iterations
# 29198 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4126
# 32107 MIP simplex iterations
# 16707 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4053
# 43347 MIP simplex iterations
# 11990 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2679
# 90563 MIP simplex iterations
# 25486 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3543
# 144363 MIP simplex iterations
# 30359 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2647
# 9516 MIP simplex iterations
# 3308 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3288
# 10524 MIP simplex iterations
# 3952 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4200
# 69834 MIP simplex iterations
# 21250 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4099
# 31784 MIP simplex iterations
# 15939 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3758
# 139802 MIP simplex iterations
# 37606 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3326
# 4725 MIP simplex iterations
# 1923 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3185
# 14390 MIP simplex iterations
# 6583 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3761
# 7062 MIP simplex iterations
# 3968 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3665
# 19147 MIP simplex iterations
# 6969 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3537
# 95070 MIP simplex iterations
# 32511 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4376
# 11161 MIP simplex iterations
# 4539 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3773
# 13214 MIP simplex iterations
# 5930 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 4446
# 26121 MIP simplex iterations
# 12381 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3139
# 8392 MIP simplex iterations
# 3982 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3291
# 3520 MIP simplex iterations
# 2182 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 3731
# 2424 MIP simplex iterations
# 734 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 2853
# 12511 MIP simplex iterations
# 6185 branch-and-bound nodes
# =========================(5, 20)XN=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 1536 MIP simplex iterations
# 474 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 72
# 127 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 133
# 1477 MIP simplex iterations
# 400 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 125
# 5145 MIP simplex iterations
# 1551 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 115
# 2856 MIP simplex iterations
# 944 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 128 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 17063 MIP simplex iterations
# 10903 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 105 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86
# 145 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 1256 MIP simplex iterations
# 400 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 693 MIP simplex iterations
# 133 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 105
# 144 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 6910 MIP simplex iterations
# 2664 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 121
# 5275 MIP simplex iterations
# 2531 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 1445 MIP simplex iterations
# 651 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 3309 MIP simplex iterations
# 924 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 4142 MIP simplex iterations
# 1578 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 151 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101
# 444 MIP simplex iterations
# 141 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 98 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 73
# 762 MIP simplex iterations
# 115 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 105
# 1890 MIP simplex iterations
# 619 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 122 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 430 MIP simplex iterations
# 89 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 120 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 79
# 672 MIP simplex iterations
# 141 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 149 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 70
# 1555 MIP simplex iterations
# 363 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
# 183 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 118
# 604 MIP simplex iterations
# 145 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 28221 MIP simplex iterations
# 18633 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 80
# 2190 MIP simplex iterations
# 809 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 2422 MIP simplex iterations
# 801 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 4478 MIP simplex iterations
# 1514 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 78
# 634 MIP simplex iterations
# 120 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 129 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 655 MIP simplex iterations
# 130 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 3647 MIP simplex iterations
# 1419 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 165 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 118
# 1780 MIP simplex iterations
# 586 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87
# 4820 MIP simplex iterations
# 1966 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 263 MIP simplex iterations
# 37 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 92 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98
# 77 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 160 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 146 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 110
# 1980 MIP simplex iterations
# 769 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 2791 MIP simplex iterations
# 1024 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 1661 MIP simplex iterations
# 558 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99
# 44892 MIP simplex iterations
# 19578 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 2072 MIP simplex iterations
# 755 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 78
# 677 MIP simplex iterations
# 145 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 2098 MIP simplex iterations
# 589 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 1713 MIP simplex iterations
# 690 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 107
# 167 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 625 MIP simplex iterations
# 132 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95
# 1809 MIP simplex iterations
# 576 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85
# 112 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 5131 MIP simplex iterations
# 2193 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106
# 18164 MIP simplex iterations
# 8417 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 112
# 7765 MIP simplex iterations
# 2703 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 117
# 1867 MIP simplex iterations
# 703 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 1776 MIP simplex iterations
# 529 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 118
# 7740 MIP simplex iterations
# 3563 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 1550 MIP simplex iterations
# 698 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 28656 MIP simplex iterations
# 10740 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 113
# 491 MIP simplex iterations
# 141 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 769 MIP simplex iterations
# 165 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94
# 632 MIP simplex iterations
# 128 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 725 MIP simplex iterations
# 146 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97
# 1509 MIP simplex iterations
# 648 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 127 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 3569 MIP simplex iterations
# 1677 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 18036 MIP simplex iterations
# 8374 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96
# 777 MIP simplex iterations
# 137 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 4539 MIP simplex iterations
# 2963 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90
# 515 MIP simplex iterations
# 124 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 124 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 116
# 1825 MIP simplex iterations
# 522 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 114
# 1640 MIP simplex iterations
# 568 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83
# 170 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92
# 724 MIP simplex iterations
# 112 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 109
# 135 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 116
# 9061 MIP simplex iterations
# 3803 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 78
# 567 MIP simplex iterations
# 96 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89
# 689 MIP simplex iterations
# 241 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93
# 116 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104
# 4303 MIP simplex iterations
# 2344 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 122
# 135 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111
# 14070 MIP simplex iterations
# 5804 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91
# 167 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 112
# 725 MIP simplex iterations
# 136 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102
# 9982 MIP simplex iterations
# 5065 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 2036 MIP simplex iterations
# 714 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103
# 1986 MIP simplex iterations
# 547 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 108
# 682 MIP simplex iterations
# 143 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 638 MIP simplex iterations
# 130 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84
# 392 MIP simplex iterations
# 128 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 119
# 3796 MIP simplex iterations
# 1250 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100
# 767 MIP simplex iterations
# 154 branch-and-bound nodes
# =========================(5, 20)RN=========================
# [98.799999999999997, 17.223000418155841, 3317.9200000000001, 99.340000000000003, 74.909999999999997, 14.156398335485132, 2584.2600000000002, 88.230000000000004, 99.879999999999995, 18.927820110993235, 3333.9400000000001, 99.099999999999994]
# [92.900000000000006, 16.365656369224414, 3245.1700000000001, 59.659999999999997, 71.209999999999994, 11.745985337660409, 2568.4299999999998, 38.579999999999998, 97.090000000000003, 17.936864280283672, 3290.9699999999998, 85.879999999999995]
# [0.94028340080971673,
#  0.95022098193601345,
#  0.97807361238366208,
#  0.60056372055566731,
#  0.95060739554131624,
#  0.82972978432072919,
#  0.99387445535665897,
#  0.43726623597415842,
#  0.97206647977573091,
#  0.94764553842446875,
#  0.98711134573507608,
#  0.86659939455095858]

# %%
MinBenefit_ijk_sn_ratio = list(map(lambda a, b: a / b, MinBenefit_ijk_sn_2, MinBenefit_ijk_sn_1))
MinBenefit_ijk_sn_ratio
# Out:
# [0.94028340080971673,
#  0.95022098193601345,
#  0.97807361238366208,
#  0.60056372055566731,
#  0.95060739554131624,
#  0.82972978432072919,
#  0.99387445535665897,
#  0.43726623597415842,
#  0.97206647977573091,
#  0.94764553842446875,
#  0.98711134573507608,
#  0.86659939455095858]

# %% [markdown]
# ## Other Function

# %%
# Increase the costs of beef and ham

cost = ampl.getParameter('cost')
cost.setValues({'BEEF': 5.01, 'HAM': 4.55})
print("Increased costs of beef and ham.")

# 再解一次

ampl.solve()
print("New objective value:", totalcost.value())

# 印出其中項目

Buy = ampl.getVariable('Buy')
print("Buy['BEEF'].val = {}".format(Buy['BEEF'].value()))

# Display the dual value of each constraint

diet = ampl.getConstraint('diet')
for nutr in nutrients:
    print("diet['{}'].dual = {}".format(nutr, diet[nutr].dual()))
# Out:
# Increased costs of beef and ham.
# CPLEX 12.8.0.0: optimal solution; objective 144.0120033
# 0 simplex iterations (0 in phase I)
# New objective value: 144.01200332502074
# Buy['BEEF'].val = 5.226932668329172
# diet['A'].dual = 0.0
# diet['C'].dual = 0.0
# diet['B1'].dual = 0.0
# diet['B2'].dual = 0.7999285120532
# diet['NA'].dual = -0.007531172069825434
# diet['CAL'].dual = 0.0
