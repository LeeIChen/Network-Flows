# %%
# Reference : https://ampl.com/api/extra/python_quickstart.html

# %% [markdown]
# ## Step 1: Path Setting

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import random
from operator import add

# %%
from bokeh.layouts import row
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="58090a2a-392a-411c-8702-1b7003062a89">Loading BokehJS ...</span>
#     </div>

# %%
from amplpy import AMPL, Environment, DataFrame

# %% [markdown]
# ## Step 2: Create an AMPL object

# %%
ampl = AMPL(Environment('C:\\Users\\user\\Desktop\\OR_Kung\\AMPL'))

# %% [markdown]
# ## Step 3: Select the solver

# %%
ampl.setOption('solver','C:\\Users\\user\\Desktop\\OR_Kung\\AMPL\\cplex')  #'gurobi'

# %% [markdown]
# ## Step 4: Define the model

# %%
# ampl.read('FairCHBF.mod')

# %%
ampl.eval('''
set I;
set J;

param B {J} >=0;   # benefit of doing the job
param C {J} >=0;   # cost of doing the job
param K {I} >=0;   # capacity of machine 

var X {I,J} >=0 binary;   # Decision var 1

maximize Benefit: sum {i in I, j in J} B[j] * X[i,j];

s.t. Capacity {i in I        }: sum {j in J} C[j] * X[i,j] <= K[i];
s.t. ProdTime {        j in J}: sum {i in I}        X[i,j] <= 1;
s.t. Arrange  {i in I, j in J}:                     X[i,j] >= 0;

''')

# %% [markdown]
# ## Step 5: Define the initial data

# %%
# batch 要做成:
# [ num_machine, num_job, cost, benefit, capacity ]

it_n = 100

def batch (num_machine, num_job, relation_bc, capacity):
    
    m = num_machine
    n = num_job
    
    list_c1 = []    # 內含 100組 n個 job的 cost 組合
    list_b1 = []    # 內含 100組 n個 job的 bnft 組合
    list_k1 = []    # 內含 100組 由 n個 job 加總算出的 k
    
    for i in range(it_n):
        
        list_c2 = []   # 內含 n個 job的 cost
        list_b2 = []   # 內含 n個 job的 bnft
        
        for j in range(n):
            c = int(random.randint(0,50))
            list_c2.append(c)

            if   relation_bc == 'L':
                b = c

            elif relation_bc == 'X':
                b = c**2

            elif relation_bc == 'A':
                b = c**(1/2)

            elif relation_bc == 'R':
                b = random.randint(0,50)  
            list_b2.append(b)

        if   capacity =='N':
            k = 10000 # no capacity

        elif capacity =='L':
            k = sum(list_c2) / m

        elif capacity =='T':
            k = sum(list_c2) * (0.75) / m
    
        list_c1.append(list_c2)
        list_b1.append(list_b2)
        list_k1.append(k)
    
    return  m, n, list_c1, list_b1, list_k1

# %%
# Test OK! 不要在正式 run 100組時  print，會很慢 >"<

instance = batch( 5, 20, 'A', 'T' )
print(instance[2])
print(instance[3])
# Out:
# [[33, 27, 40, 46, 22, 14, 36, 48, 16, 39, 50, 35, 10, 50, 42, 13, 27, 38, 32, 49]]
# [[5.744562646538029, 5.196152422706632, 6.324555320336759, 6.782329983125268, 4.69041575982343, 3.7416573867739413, 6.0, 6.928203230275509, 4.0, 6.244997998398398, 7.0710678118654755, 5.916079783099616, 3.1622776601683795, 7.0710678118654755, 6.48074069840786, 3.605551275463989, 5.196152422706632, 6.164414002968976, 5.656854249492381, 7.0]]

# %%
machine_job  = [(5,20)]
capacity     = ['L','T','N'] 
relation_bc  = ['L','A','X','R']

# %% [markdown]
# ## Step 6: Model Build-up & Solution

# %%
# 迭代 instance

TotalBenefit_ijk_sn_1 = []
TotalBenefit_ijk_sn_2 = []

for i in machine_job:
    
    num_machine = i[0]
    num_job     = i[1]

    # 印出編號，但從1開始算而不是從0，再讓 [1,2,3] -> [M1,M2,M3]

    machine1 = ['M']*num_machine
    job1     = ['J']*num_job
    machine2 = map(add, list(range(num_machine)), [1]*num_machine)
    job2     = map(add, list(range(num_job))    , [1]*num_job)
    machine2 = list( str(x) for x in machine2 )
    job2     = list( str(x) for x in job2     )
    machine  = list (map(lambda y, z: y + z, machine1, machine2))
    job      = list (map(lambda y, z: y + z, job1,     job2    ))

    # AMPL sets

    ampl.getSet('I').setValues(machine)
    ampl.getSet('J').setValues(job)
    
    for k in capacity:    
        for j in relation_bc:

            instance = batch( i[0], i[1], j, k )
            #print(instance)  
            
            TotalBenefit_1 = []
            TotalBenefit_2 = []
            
            for p in range(it_n):      
                
                # ====== Model 1 ======= : 一組一組用solver算 IP (or linear relaxed LP)，每種senario要算 100組 再平均
                
                # amplpy DataFrame
                ampl.setData(DataFrame(
                index=[('J', job)], 
                columns=[
                    ('B', instance[3][p]), 
                    ('C', instance[2][p])
                ]
                ))

                # Pandas DataFrame
                df = pd.DataFrame({
                    'K': [ instance[4][p] ]*num_machine
                }, 
                    index = machine
                )
                ampl.setData(DataFrame.fromPandas(df))

                # Solve the problem
                ampl.solve()

                '''
                # Create a DataFrame with Decision variables
                Var = ampl.getVariable('X').getValues().toPandas()
                print(Var)
                '''

                # Display the objective value
                TotalBnft_1 = ampl.getObjective('Benefit')
                TotalBnft_1 = TotalBnft_1.value()
                TotalBenefit_1 = np.append(TotalBenefit_1, TotalBnft_1) # numpy.ndarray
                
                
                # ====== Model 2 ======= : 一組一組用 CHBF算，每種senario要算 100組 再平均
                
                # 將 job 按照 cost (workload) 排序

                list_c = instance[2][p]
                list_b = instance[3][p]

                list_cb = list(zip(list_c, list_b))        # [3,5]  [8,1]  -> [(3,8),(5,1)]
                s_cb    = sorted(list_cb, reverse = True)  # [(3,8),(5,1)] -> [(5,1),(3,8)]
                o_cb    = list(zip(*s_cb))                 # [(5,1),(3,8)] -> [(5,3),(1,8)]

                list_c  = list(o_cb[0])                    # [5,3]
                list_b  = list(o_cb[1])                    # [1,8]

                mach = []                 # machine
                ca = instance[4][p]

                for r in range(num_machine):

                    mach.append([])    # machine set中安排一台台 machine 被 append 進來
                    mach[r].append(0)  # 初始的 benefit和 是 0
                    mach[r].append(ca) # 初始的 capacity  是 ca

                TotalBnft_2 = 0             
                for s in range(num_job):

                    mach = sorted(mach)                           # 按照 benefit和 由小而大排序
                    # print(machine)

                    for r in range(num_machine):                  # 由最小 benefit和 的先開始
                        
                        if list_c[s] <= mach[r][1]:               # machine r 還有 capacity 餘裕
                            
                            #print(mach[r])
                            mach[r][1] -= list_c[s]
                            mach[r][0] += list_b[s]
                            #print(mach[r])
 
                            break
    
                for r in range(num_machine):                  
                    TotalBnft_2 += mach[r][0]                           # 將所有 machine 的 benefit和加起來成為一組
                    #print(mach[r][0])
                    
                TotalBenefit_2 = np.append(TotalBenefit_2, TotalBnft_2) # 將 100組全 append在一起 
                #print(TotalBenefit_2)
                
                
            # ====== Model 1 Objective value: ====== #
            
            list_M1           = list(TotalBenefit_1)
            TotalBenefit_100_1 = sum(list_M1) / len(list_M1)
            TotalBenefit_ijk_sn_1.append(TotalBenefit_100_1)   # i*j*k 種 senario 迭代
            
            # ====== Model 2 Objective value: ====== #
            
            list_M2           = list(TotalBenefit_2)
            TotalBenefit_100_2 = sum(list_M2) / len(list_M2)
            TotalBenefit_ijk_sn_2.append(TotalBenefit_100_2)  # i*j*k 種 senario 迭代
            
            print('=========================' + str(i) + str(j) + str(k) + '=========================') # 分隔           
            
print(TotalBenefit_ijk_sn_1) # list
print(TotalBenefit_ijk_sn_2) # list

TotalBenefit_ijk_sn_ratio = list(map(lambda a, b: a / b, TotalBenefit_ijk_sn_2, TotalBenefit_ijk_sn_1))
TotalBenefit_ijk_sn_ratio
# Out:
# CPLEX 12.8.0.0: optimal integer solution; objective 560
# 120 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 525
# 4841 MIP simplex iterations
# 1169 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 458
# 1593 MIP simplex iterations
# 370 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 495
# 4815 MIP simplex iterations
# 1147 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 495
# 115 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 681
# 619 MIP simplex iterations
# 116 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 599
# 568 MIP simplex iterations
# 94 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 444
# 15352 MIP simplex iterations
# 5087 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 510
# 139 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 408
# 633 MIP simplex iterations
# 146 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 500
# 591 MIP simplex iterations
# 101 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 450
# 93 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 543
# 1213770 MIP simplex iterations
# 244574 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 580
# 1308 MIP simplex iterations
# 251 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 640
# 27313 MIP simplex iterations
# 4620 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 425
# 1685 MIP simplex iterations
# 394 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 423
# 131 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 563
# 584 MIP simplex iterations
# 127 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 524
# 115 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 398
# 141 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 505
# 551 MIP simplex iterations
# 125 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 424
# 140 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 497
# 158 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 480
# 9100 MIP simplex iterations
# 1684 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 459
# 10060 MIP simplex iterations
# 1128 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 466
# 512 MIP simplex iterations
# 107 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 364
# 80726 MIP simplex iterations
# 17320 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 555
# 1392 MIP simplex iterations
# 331 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 565
# 92 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 612
# 37288 MIP simplex iterations
# 7262 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 420
# 603 MIP simplex iterations
# 88 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 525
# 19177 MIP simplex iterations
# 3276 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 493
# 109 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 519
# 131 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 450
# 122 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 405
# 97 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 513
# 1431 MIP simplex iterations
# 520 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 553
# 976 MIP simplex iterations
# 273 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 475
# 2512 MIP simplex iterations
# 848 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 499
# 43598 MIP simplex iterations
# 6831 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 390
# 124 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 520
# 589 MIP simplex iterations
# 89 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 495
# 4743 MIP simplex iterations
# 1077 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 508
# 394 MIP simplex iterations
# 78 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 549
# 136 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 569
# 195189 MIP simplex iterations
# 37603 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 499
# 104 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 455
# 125 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 595
# 1972 MIP simplex iterations
# 379 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 500
# 8256 MIP simplex iterations
# 1579 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 453
# 574 MIP simplex iterations
# 127 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 520
# 29018 MIP simplex iterations
# 4837 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 444
# 117 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 310
# 119 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 489
# 33288 MIP simplex iterations
# 8386 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 480
# 1976 MIP simplex iterations
# 394 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 482
# 108 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 375
# 3744 MIP simplex iterations
# 768 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 430
# 133 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 461
# 111 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 453
# 147 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 520
# 5485 MIP simplex iterations
# 1293 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 515
# 1849 MIP simplex iterations
# 398 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 460
# 1964 MIP simplex iterations
# 387 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 490
# 2280 MIP simplex iterations
# 429 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 480
# 89 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 455
# 93 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 612
# 565 MIP simplex iterations
# 101 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 490
# 1862 MIP simplex iterations
# 399 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 479
# 514 MIP simplex iterations
# 112 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 485
# 619 MIP simplex iterations
# 127 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 497
# 150 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 573
# 3950 MIP simplex iterations
# 989 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 500
# 1685 MIP simplex iterations
# 350 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 497
# 34473 MIP simplex iterations
# 6809 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 413
# 1387 MIP simplex iterations
# 335 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 405
# 639 MIP simplex iterations
# 123 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 565
# 6059 MIP simplex iterations
# 1405 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 462
# 46545 MIP simplex iterations
# 9248 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 483
# 1058 MIP simplex iterations
# 371 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 480
# 94 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 504
# 1759098 MIP simplex iterations
# 201189 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 495
# 2255 MIP simplex iterations
# 446 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 542
# 131 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 439
# 326 MIP simplex iterations
# 40 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 460
# 5040 MIP simplex iterations
# 1129 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 502
# 135 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 526
# 26859 MIP simplex iterations
# 5027 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 509
# 569 MIP simplex iterations
# 115 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 485
# 2640 MIP simplex iterations
# 459 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 530
# 7351 MIP simplex iterations
# 1620 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 510
# 13847 MIP simplex iterations
# 1858 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 535
# 6032 MIP simplex iterations
# 1524 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 515
# 659 MIP simplex iterations
# 114 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 555
# 639 MIP simplex iterations
# 104 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 566
# 109 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 510
# 526 MIP simplex iterations
# 122 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 340
# 77 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 465
# 3399 MIP simplex iterations
# 809 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 470
# 94 MIP simplex iterations
# 0 branch-and-bound nodes
# =========================(5, 20)LL=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 91.84472552
# 108 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 103.4126403
# 26625 MIP simplex iterations
# 5548 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.46046087
# 30276 MIP simplex iterations
# 6810 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92.01834456
# 35068 MIP simplex iterations
# 6883 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100.4804702
# 32452 MIP simplex iterations
# 5000 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100.3604756
# 17704 MIP simplex iterations
# 3119 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90.3620051
# 92 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88.37667227
# 6276 MIP simplex iterations
# 1674 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87.96120879
# 81 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99.09413194
# 40862 MIP simplex iterations
# 7481 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91.80721101
# 402 MIP simplex iterations
# 129 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93.86872439
# 7626 MIP simplex iterations
# 1781 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90.27444344
# 807 MIP simplex iterations
# 209 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94.03760748
# 56094 MIP simplex iterations
# 11562 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 90.21985426
# 448895 MIP simplex iterations
# 127228 branch-and-bound nodes
# absmipgap = 0.00882092, relmipgap = 9.77714e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 99.6952436
# 3197 MIP simplex iterations
# 1099 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94.0153729
# 38256 MIP simplex iterations
# 9403 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88.44247789
# 30106 MIP simplex iterations
# 5146 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94.09736252
# 69 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91.2169802
# 24752 MIP simplex iterations
# 4310 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.97542689
# 1853 MIP simplex iterations
# 429 branch-and-bound nodes
# absmipgap = 1.42109e-14, relmipgap = 1.67235e-16
# CPLEX 12.8.0.0: optimal integer solution; objective 103.5555567
# 26301 MIP simplex iterations
# 5187 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101.4222803
# 1154 MIP simplex iterations
# 332 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93.72620047
# 23867 MIP simplex iterations
# 4752 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 95.97227678
# 75 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98.6050754
# 25634 MIP simplex iterations
# 5461 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96.22134511
# 27612 MIP simplex iterations
# 6775 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.93309247
# 294 MIP simplex iterations
# 78 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93.60127048
# 1603 MIP simplex iterations
# 362 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106.3418696
# 111 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 88.52325015
# 858121 MIP simplex iterations
# 282505 branch-and-bound nodes
# absmipgap = 0.00814887, relmipgap = 9.20535e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 95.66593291
# 24663 MIP simplex iterations
# 4769 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91.42944734
# 619 MIP simplex iterations
# 133 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97.60160745
# 104 MIP simplex iterations
# 0 branch-and-bound nodes
# absmipgap = 1.42109e-14, relmipgap = 1.45601e-16
# CPLEX 12.8.0.0: optimal integer solution; objective 96.8629021
# 743 MIP simplex iterations
# 129 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92.59950451
# 530 MIP simplex iterations
# 109 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.76018483
# 30982 MIP simplex iterations
# 6166 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90.94027448
# 33276 MIP simplex iterations
# 7754 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99.353646
# 7951 MIP simplex iterations
# 1532 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 93.51897322
# 1150 MIP simplex iterations
# 298 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86.5612363
# 27479 MIP simplex iterations
# 6466 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101.0824513
# 24584 MIP simplex iterations
# 4915 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89.7447763
# 529 MIP simplex iterations
# 106 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88.23117981
# 40942 MIP simplex iterations
# 6101 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100.3698781
# 25677 MIP simplex iterations
# 5229 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86.53290504
# 56270 MIP simplex iterations
# 11722 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 85.24303858
# 22565 MIP simplex iterations
# 4227 branch-and-bound nodes
# absmipgap = 0.00425529, relmipgap = 4.99195e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 86.34408995
# 31078 MIP simplex iterations
# 6503 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 94.87033101
# 4421718 MIP simplex iterations
# 1488790 branch-and-bound nodes
# absmipgap = 0.00924812, relmipgap = 9.74817e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 84.86029334
# 20242 MIP simplex iterations
# 5068 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102.2046763
# 106 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100.3815901
# 5345 MIP simplex iterations
# 1251 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99.64156862
# 88 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 86.50151578
# 17320 MIP simplex iterations
# 3546 branch-and-bound nodes
# absmipgap = 1.42109e-14, relmipgap = 1.64284e-16
# CPLEX 12.8.0.0: optimal integer solution; objective 95.41245855
# 45462 MIP simplex iterations
# 7392 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.60963424
# 2236 MIP simplex iterations
# 719 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104.0349557
# 2007 MIP simplex iterations
# 520 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88.12957782
# 155 MIP simplex iterations
# 12 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100.5711968
# 25708 MIP simplex iterations
# 4859 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90.90576395
# 84 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 98.238856
# 475 MIP simplex iterations
# 118 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96.89753257
# 26186 MIP simplex iterations
# 5960 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 104.8256309
# 1057 MIP simplex iterations
# 263 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101.5254814
# 1532 MIP simplex iterations
# 378 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102.2383932
# 29794 MIP simplex iterations
# 6539 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87.12495926
# 35553 MIP simplex iterations
# 6563 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.33557077
# 118 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 106.8138571
# 134 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99.45854675
# 39073 MIP simplex iterations
# 8839 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92.23330817
# 30789 MIP simplex iterations
# 6762 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90.33830708
# 3273 MIP simplex iterations
# 649 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90.96545016
# 34457 MIP simplex iterations
# 6629 branch-and-bound nodes
# absmipgap = 1.42109e-14, relmipgap = 1.56223e-16
# CPLEX 12.8.0.0: optimal integer solution; objective 96.81111832
# 3579 MIP simplex iterations
# 808 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88.54221641
# 29727 MIP simplex iterations
# 6557 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87.89970761
# 15881 MIP simplex iterations
# 2995 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 101.7228713
# 2051 MIP simplex iterations
# 649 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94.80667317
# 26668 MIP simplex iterations
# 5278 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 96.66119007
# 7596 MIP simplex iterations
# 1913 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 75.12155802
# 86 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 99.40459254
# 123 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94.53834737
# 1802 MIP simplex iterations
# 422 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 91.69309651
# 28243 MIP simplex iterations
# 6905 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 111.7325394
# 1278 MIP simplex iterations
# 285 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 92.55909288
# 24010 MIP simplex iterations
# 4987 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88.42066411
# 2552 MIP simplex iterations
# 482 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 94.89569597
# 28023 MIP simplex iterations
# 6296 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 88.10417473
# 1433 MIP simplex iterations
# 435 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 100.4473578
# 37067 MIP simplex iterations
# 5835 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.6464134
# 935 MIP simplex iterations
# 189 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.49135907
# 68534 MIP simplex iterations
# 25258 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89.6632256
# 2769 MIP simplex iterations
# 773 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 102.991428
# 1235 MIP simplex iterations
# 327 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 90.15668896
# 126 MIP simplex iterations
# 0 branch-and-bound nodes
# absmipgap = 1.42109e-14, relmipgap = 1.57624e-16
# CPLEX 12.8.0.0: optimal integer solution; objective 89.15230684
# 25495 MIP simplex iterations
# 5290 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 77.11244762
# 105500 MIP simplex iterations
# 36725 branch-and-bound nodes
# absmipgap = 0.00362317, relmipgap = 4.69855e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 84.64137615
# 451 MIP simplex iterations
# 86 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 97.60280012
# 26684 MIP simplex iterations
# 5176 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 87.68009024
# 458 MIP simplex iterations
# 117 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 89.75240743
# 80 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.79882309
# 20521 MIP simplex iterations
# 5078 branch-and-bound nodes
# =========================(5, 20)AL=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 19039
# 860 MIP simplex iterations
# 254 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14573
# 110 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 10511
# 1157 MIP simplex iterations
# 419 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14574
# 476 MIP simplex iterations
# 117 branch-and-bound nodes
# absmipgap = 1, relmipgap = 6.86153e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 22511
# 148 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 9873
# 93 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 21124
# 3053 MIP simplex iterations
# 972 branch-and-bound nodes
# absmipgap = 2, relmipgap = 9.4679e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 13875
# 524 MIP simplex iterations
# 146 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16533
# 138 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14030
# 3866 MIP simplex iterations
# 1257 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18038
# 7976 MIP simplex iterations
# 2252 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 19217
# 607 MIP simplex iterations
# 180 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 15951
# 1347 MIP simplex iterations
# 478 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 19426
# 2025 MIP simplex iterations
# 631 branch-and-bound nodes
# absmipgap = 1.2, relmipgap = 6.17729e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 14821
# 72 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14796
# 3269 MIP simplex iterations
# 1129 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16029
# 399 MIP simplex iterations
# 153 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14348
# 166 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 21443
# 126 MIP simplex iterations
# 0 branch-and-bound nodes
# absmipgap = 1, relmipgap = 4.66353e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 14995
# 10553 MIP simplex iterations
# 2373 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 20789
# 434 MIP simplex iterations
# 143 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 12914
# 394 MIP simplex iterations
# 117 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14715
# 1430 MIP simplex iterations
# 589 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 15875
# 24270 MIP simplex iterations
# 6783 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18832
# 11197 MIP simplex iterations
# 2962 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 13525
# 86 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18199
# 1362 MIP simplex iterations
# 412 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 15007
# 96 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16362
# 1084 MIP simplex iterations
# 271 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17196
# 12412 MIP simplex iterations
# 2989 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 13753
# 1007 MIP simplex iterations
# 277 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17233
# 109 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18113
# 108 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14137
# 106 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 23311
# 530 MIP simplex iterations
# 105 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 15962
# 105 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16380
# 503 MIP simplex iterations
# 94 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14997
# 3152 MIP simplex iterations
# 849 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 15553
# 454 MIP simplex iterations
# 126 branch-and-bound nodes
# absmipgap = 1, relmipgap = 6.42963e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18563
# 17691 MIP simplex iterations
# 3407 branch-and-bound nodes
# absmipgap = 1, relmipgap = 5.38706e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 14593
# 3317 MIP simplex iterations
# 956 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18369
# 145 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16514
# 118 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14716
# 1563 MIP simplex iterations
# 488 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 22310
# 11297 MIP simplex iterations
# 2473 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 20882
# 126 MIP simplex iterations
# 10 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17473
# 697 MIP simplex iterations
# 126 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 22210
# 1327 MIP simplex iterations
# 361 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16105
# 126 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 22941
# 129 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14095
# 451 MIP simplex iterations
# 129 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 11989
# 89 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 6385
# 104 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18925
# 2485 MIP simplex iterations
# 611 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17173
# 107 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 21683
# 1850 MIP simplex iterations
# 532 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17628
# 83 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16208
# 543 MIP simplex iterations
# 123 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17579
# 1731 MIP simplex iterations
# 455 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 8235
# 98 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 12611
# 2606 MIP simplex iterations
# 890 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 22022
# 6045 MIP simplex iterations
# 1422 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 19134
# 1485 MIP simplex iterations
# 438 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 19939
# 2392 MIP simplex iterations
# 386 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 18792
# 452 MIP simplex iterations
# 115 branch-and-bound nodes
# absmipgap = 1, relmipgap = 5.32141e-05
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14847
# 530 MIP simplex iterations
# 132 branch-and-bound nodes
# absmipgap = 1, relmipgap = 6.73537e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 20673
# 9914 MIP simplex iterations
# 3458 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18632
# 16732 MIP simplex iterations
# 3501 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18212
# 5818 MIP simplex iterations
# 1118 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 19654
# 1332 MIP simplex iterations
# 457 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16103
# 469 MIP simplex iterations
# 105 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16037
# 122 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 21526
# 93 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 14929
# 2072 MIP simplex iterations
# 792 branch-and-bound nodes
# absmipgap = 1, relmipgap = 6.69837e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 13353
# 674 MIP simplex iterations
# 193 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 11930
# 3333 MIP simplex iterations
# 1352 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14883
# 395 MIP simplex iterations
# 131 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 13263
# 91 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17300
# 462 MIP simplex iterations
# 76 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17658
# 1575 MIP simplex iterations
# 515 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 20879
# 3938 MIP simplex iterations
# 1262 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 10370
# 76 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18823
# 119 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18298
# 573 MIP simplex iterations
# 195 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 19820
# 108 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 10676
# 112 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14207
# 100 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18461
# 123 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14341
# 105 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 15766
# 104 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 12265
# 1658 MIP simplex iterations
# 544 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution within mipgap or absmipgap; objective 17602
# 4902 MIP simplex iterations
# 1153 branch-and-bound nodes
# absmipgap = 1, relmipgap = 5.68117e-05
# CPLEX 12.8.0.0: optimal integer solution; objective 21764
# 113 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 11743
# 2240 MIP simplex iterations
# 753 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 21915
# 3929 MIP simplex iterations
# 1227 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17675
# 4377 MIP simplex iterations
# 1479 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17205
# 156 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14368
# 549 MIP simplex iterations
# 118 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17610
# 1457 MIP simplex iterations
# 344 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 20984
# 2034 MIP simplex iterations
# 609 branch-and-bound nodes
# =========================(5, 20)XL=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 608
# 73 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 546
# 100 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 542
# 1212 MIP simplex iterations
# 541 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 517
# 1695 MIP simplex iterations
# 377 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 540
# 92 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 388
# 54 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 364
# 41 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 510
# 88 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 422
# 46 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 469
# 43 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 540
# 45 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 517
# 16957 MIP simplex iterations
# 5426 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 533
# 38 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 504
# 365 MIP simplex iterations
# 173 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 315
# 45 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 586
# 54 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 499
# 103 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 418
# 95 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 418
# 51 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 558
# 1607 MIP simplex iterations
# 645 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 583
# 16102 MIP simplex iterations
# 3424 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 524
# 97 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 442
# 67 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 488
# 62 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 456
# 2303 MIP simplex iterations
# 522 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 462
# 43 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 348
# 106 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 328
# 86 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 491
# 22090 MIP simplex iterations
# 5099 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 464
# 2806 MIP simplex iterations
# 1161 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 455
# 47 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 538
# 448 MIP simplex iterations
# 154 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 483
# 45 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 374
# 62 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 511
# 50 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 460
# 45 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 522
# 4585 MIP simplex iterations
# 1424 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 414
# 41 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 398
# 48 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 454
# 75 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 525
# 1495 MIP simplex iterations
# 807 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 502
# 83 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 525
# 93 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 449
# 48 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 507
# 131 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 499
# 53 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 568
# 2175 MIP simplex iterations
# 721 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 377
# 1666 MIP simplex iterations
# 515 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 504
# 57 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 416
# 16738 MIP simplex iterations
# 5299 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 407
# 470 MIP simplex iterations
# 224 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 513
# 46 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 584
# 10950 MIP simplex iterations
# 2881 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 522
# 126 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 535
# 16474 MIP simplex iterations
# 5247 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 502
# 49 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 478
# 45 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 553
# 44 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 562
# 163 MIP simplex iterations
# 41 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 513
# 106 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 659
# 84 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 543
# 786 MIP simplex iterations
# 421 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 609
# 82 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 458
# 58 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 495
# 14638 MIP simplex iterations
# 5202 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 602
# 87 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 534
# 1630 MIP simplex iterations
# 892 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 527
# 40 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 566
# 86 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 616
# 93 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 468
# 45 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 477
# 3483 MIP simplex iterations
# 855 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 488
# 84 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 543
# 60 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 461
# 90 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 485
# 94 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 494
# 74 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 533
# 48 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 545
# 1314 MIP simplex iterations
# 257 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 496
# 1916 MIP simplex iterations
# 584 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 400
# 46 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 579
# 93 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 438
# 47 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 483
# 81 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 481
# 42 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 548
# 56 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 486
# 88 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 472
# 50 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 660
# 64 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 533
# 2448 MIP simplex iterations
# 1180 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 507
# 86 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 480
# 40 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 523
# 1704 MIP simplex iterations
# 415 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 552
# 49 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 384
# 46 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 637
# 77 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 596
# 117 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 600
# 69 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 534
# 87 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 519
# 3713 MIP simplex iterations
# 1595 branch-and-bound nodes
# =========================(5, 20)RL=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 320
# 21 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 420
# 2611 MIP simplex iterations
# 561 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 380
# 600 MIP simplex iterations
# 100 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 275
# 382 MIP simplex iterations
# 70 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 420
# 8680 MIP simplex iterations
# 2143 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 530
# 2290 MIP simplex iterations
# 451 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 320
# 110 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 325
# 54 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 300
# 9473 MIP simplex iterations
# 2037 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 320
# 466 MIP simplex iterations
# 122 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 395
# 1672 MIP simplex iterations
# 432 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 330
# 481 MIP simplex iterations
# 94 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 410
# 88 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 500
# 5637 MIP simplex iterations
# ...
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14445
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18283
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 23054
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16651
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 19405
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 12179
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 13354
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17121
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17618
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 17303
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 11666
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14810
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 9644
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 12382
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16731
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16515
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 23929
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 15677
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14486
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 15001
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 22521
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16567
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14912
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14203
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 22318
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 16605
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 23121
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 25241
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 19524
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 10960
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 20463
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 20836
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18981
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14284
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14930
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 11694
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 20086
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 18855
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 14067
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 22188
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 9236
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 15093
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# =========================(5, 20)XN=========================
# CPLEX 12.8.0.0: optimal integer solution; objective 390
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 604
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 513
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 457
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 495
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 534
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 558
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 565
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 580
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 380
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 483
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 566
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 373
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 477
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 502
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 477
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 354
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 467
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 372
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 405
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 502
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 585
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 568
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 482
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 509
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 401
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 550
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 528
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 532
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 535
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 452
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 529
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 382
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 458
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 654
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 437
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 436
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 426
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 340
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 508
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 586
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 590
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 455
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 510
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 544
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 497
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 484
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 402
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 572
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 572
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 461
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 461
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 460
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 443
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 452
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 478
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 284
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 514
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 453
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 569
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 461
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 442
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 645
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 504
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 468
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 585
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 554
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 578
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 589
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 350
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 538
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 407
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 489
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 546
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 488
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 558
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 464
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 481
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 510
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 511
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 494
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 417
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 589
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 604
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 526
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 437
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 449
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 423
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 622
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 497
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 499
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 557
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 500
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 510
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 415
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 355
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 472
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 446
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 541
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 518
# 0 MIP simplex iterations
# 0 branch-and-bound nodes
# =========================(5, 20)RN=========================
# [492.95999999999998, 93.279358038109152, 16694.060000000001, 500.41000000000003, 375.38999999999999, 73.168405272704561, 13401.040000000001, 463.26999999999998, 495.44, 92.682133724164302, 16898.439999999999, 491.92000000000002]
# [475.06, 89.609358229682016, 16421.330000000002, 472.51999999999998, 362.47000000000003, 62.716151695088641, 13165.610000000001, 321.76999999999998, 495.44, 92.682133724164302, 16898.439999999999, 491.92000000000002]
# [0.96368873742291472,
#  0.96065582047715459,
#  0.98366305140870469,
#  0.94426570212425798,
#  0.96558246090732314,
#  0.85714799251590179,
#  0.98243196050455783,
#  0.69456256610615841,
#  1.0,
#  1.0,
#  1.0,
#  1.0]

# %%
TotalBenefit_ijk_sn_ratio = list(map(lambda a, b: a / b, TotalBenefit_ijk_sn_2, TotalBenefit_ijk_sn_1))
TotalBenefit_ijk_sn_ratio
# Out:
# [0.96368873742291472,
#  0.96065582047715459,
#  0.98366305140870469,
#  0.94426570212425798,
#  0.96558246090732314,
#  0.85714799251590179,
#  0.98243196050455783,
#  0.69456256610615841,
#  1.0,
#  1.0,
#  1.0,
#  1.0]

# %% [markdown]
# ## Other Function

# %%
# Increase the costs of beef and ham

cost = ampl.getParameter('cost')
cost.setValues({'BEEF': 5.01, 'HAM': 4.55})
print("Increased costs of beef and ham.")

# 再解一次

ampl.solve()
print("New objective value:", totalcost.value())

# 印出其中項目

Buy = ampl.getVariable('Buy')
print("Buy['BEEF'].val = {}".format(Buy['BEEF'].value()))

# Display the dual value of each constraint

diet = ampl.getConstraint('diet')
for nutr in nutrients:
    print("diet['{}'].dual = {}".format(nutr, diet[nutr].dual()))
# Out:
# Increased costs of beef and ham.
# CPLEX 12.8.0.0: optimal solution; objective 144.0120033
# 0 simplex iterations (0 in phase I)
# New objective value: 144.01200332502074
# Buy['BEEF'].val = 5.226932668329172
# diet['A'].dual = 0.0
# diet['C'].dual = 0.0
# diet['B1'].dual = 0.0
# diet['B2'].dual = 0.7999285120532
# diet['NA'].dual = -0.007531172069825434
# diet['CAL'].dual = 0.0
